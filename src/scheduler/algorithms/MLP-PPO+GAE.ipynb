# %%
pip install "gymnasium[classic-control]" stable-baselines3 sb3-contrib pyyaml pydantic
# Out:
# Requirement already satisfied: stable-baselines3 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (2.7.1)
# Requirement already satisfied: sb3-contrib in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (2.7.1)
# Collecting pyyaml
#   Using cached pyyaml-6.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting pydantic
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: gymnasium[classic-control] in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from gymnasium[classic-control]) (2.4.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from gymnasium[classic-control]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from gymnasium[classic-control]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from gymnasium[classic-control]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from gymnasium[classic-control]) (2.6.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from stable-baselines3) (2.10.0)
# Requirement already satisfied: pandas in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from stable-baselines3) (3.0.1)
# Requirement already satisfied: matplotlib in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from stable-baselines3) (3.10.8)
# Requirement already satisfied: filelock in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.24.3)
# Requirement already satisfied: setuptools in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (82.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from cuda-bindings==12.9.4->torch<3.0,>=2.3->stable-baselines3) (1.3.4)
# Collecting annotated-types>=0.6.0 (from pydantic)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic)
#   Using cached pydantic_core-2.41.5-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from matplotlib->stable-baselines3) (26.0)
# Requirement already satisfied: pillow>=8 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from matplotlib->stable-baselines3) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from matplotlib->stable-baselines3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Using cached pyyaml-6.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (801 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pyyaml, pydantic-core, annotated-types, pydantic
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [pydantic]━━ 4/5 [pydantic]
# Successfully installed annotated-types-0.7.0 pydantic-2.12.5 pydantic-core-2.41.5 pyyaml-6.0.3 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall -y torch torchvision torchaudio torchdata torchtext dgl
# Out:
# Found existing installation: torch 2.10.0
# Uninstalling torch-2.10.0:
#   Successfully uninstalled torch-2.10.0
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# WARNING: Skipping torchdata as it is not installed.
# WARNING: Skipping torchtext as it is not installed.
# Found existing installation: dgl 0.1.3
# Uninstalling dgl-0.1.3:
#   Successfully uninstalled dgl-0.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch==2.1.2
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==2.1.2 (from versions: 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0)
# ERROR: No matching distribution found for torch==2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchdata==0.7.1
# Out:
# Collecting torchdata==0.7.1
#   Downloading torchdata-0.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: urllib3>=1.25 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torchdata==0.7.1) (2.6.3)
# Requirement already satisfied: requests in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torchdata==0.7.1) (2.32.5)
# Collecting torch>=2 (from torchdata==0.7.1)
#   Downloading torch-2.11.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch>=2->torchdata==0.7.1) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch>=2->torchdata==0.7.1) (4.15.0)
# Collecting setuptools<82 (from torch>=2->torchdata==0.7.1)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: sympy>=1.13.3 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch>=2->torchdata==0.7.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch>=2->torchdata==0.7.1) (3.6.1)
# Requirement already satisfied: jinja2 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch>=2->torchdata==0.7.1) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch>=2->torchdata==0.7.1) (2026.2.0)
# Collecting cuda-toolkit==13.0.2 (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading cuda_toolkit-13.0.2-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting cuda-bindings<14,>=13.0.3 (from torch>=2->torchdata==0.7.1)
#   Downloading cuda_bindings-13.2.0-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Collecting nvidia-cudnn-cu13==9.19.0.56 (from torch>=2->torchdata==0.7.1)
#   Downloading nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Collecting nvidia-cusparselt-cu13==0.8.0 (from torch>=2->torchdata==0.7.1)
#   Downloading nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting nvidia-nccl-cu13==2.28.9 (from torch>=2->torchdata==0.7.1)
#   Downloading nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu13==3.4.5 (from torch>=2->torchdata==0.7.1)
#   Downloading nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: triton==3.6.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from torch>=2->torchdata==0.7.1) (3.6.0)
# Collecting nvidia-cublas==13.1.0.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading nvidia_cublas-13.1.0.3-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime==13.0.96.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft==12.0.0.61.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cufile==1.15.1.6.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand==10.4.0.35.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver==12.0.4.66.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse==12.6.3.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink==13.0.88.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-nvrtc==13.0.88.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvtx==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2->torchdata==0.7.1)
#   Downloading nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2->torchdata==0.7.1) (1.3.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from sympy>=1.13.3->torch>=2->torchdata==0.7.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from jinja2->torch>=2->torchdata==0.7.1) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from requests->torchdata==0.7.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from requests->torchdata==0.7.1) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from requests->torchdata==0.7.1) (2026.2.25)
# Downloading torchdata-0.7.1-py3-none-any.whl (184 kB)
# Downloading torch-2.11.0-cp313-cp313-manylinux_2_28_x86_64.whl (530.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.7/530.7 MB 7.6 MB/s  0:01:05 eta 0:00:010:00:02m
# Downloading cuda_toolkit-13.0.2-py2.py3-none-any.whl (2.4 kB)
# Downloading nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl (366.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 8.5 MB/s  0:00:44 eta 0:00:010:00:02
# Downloading nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl (169.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 MB 8.3 MB/s  0:00:20 eta 0:00:010:00:01
# Downloading nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl (196.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 MB 4.4 MB/s  0:00:37 eta 0:00:010:00:02
# Downloading nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (60.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 7.6 MB/s  0:00:07 eta 0:00:010:00:01
# Downloading cuda_bindings-13.2.0-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 5.6 MB/s  0:00:01m 5.7 MB/s eta 0:00:01
# Downloading nvidia_cublas-13.1.0.3-py3-none-manylinux_2_27_x86_64.whl (423.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 9.0 MB/s  0:00:54 eta 0:00:010:00:02
# Downloading nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 13.8 MB/s  0:00:00.1 MB/s eta 0:00:01:01
# Downloading nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (90.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 7.5 MB/s  0:00:11 eta 0:00:010:01:02m
# Downloading nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.7 MB/s  0:00:00m 9.8 MB/s eta 0:00:01
# Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (214.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 5.3 MB/s  0:00:36 eta 0:00:010:00:02
# Downloading nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.7 MB/s  0:00:00
# Downloading nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl (59.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 8.5 MB/s  0:00:06a 0:00:010:00:01:01m
# Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl (200.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 MB 8.5 MB/s  0:00:23 eta 0:00:010:00:01
# Downloading nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (145.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 MB 7.9 MB/s  0:00:18 eta 0:00:010:00:01
# Downloading nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (40.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 MB 6.6 MB/s  0:00:06m 6.6 MB/s eta 0:00:01
# Downloading nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (148 kB)
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.4 MB/s  0:00:00
# Installing collected packages: nvidia-cusparselt-cu13, cuda-toolkit, setuptools, nvidia-nvtx, nvidia-nvshmem-cu13, nvidia-nvjitlink, nvidia-nccl-cu13, nvidia-curand, nvidia-cufile, nvidia-cuda-runtime, nvidia-cuda-nvrtc, nvidia-cuda-cupti, nvidia-cublas, cuda-bindings, nvidia-cusparse, nvidia-cufft, nvidia-cudnn-cu13, nvidia-cusolver, torch, torchdata
#   Attempting uninstall: setuptools━━━━━━━━━━━━━━━━━━━━  0/20 [nvidia-cusparselt-cu13]
#     Found existing installation: setuptools 82.0.0  0/20 [nvidia-cusparselt-cu13]
#     Uninstalling setuptools-82.0.0:━━━━━━━━━━━━━━━  0/20 [nvidia-cusparselt-cu13]
#       Successfully uninstalled setuptools-82.0.0━━  0/20 [nvidia-cusparselt-cu13]
#   Attempting uninstall: cuda-bindings━━━━━━━━╺━━━━━━━━━━━━━━━ 12/20 [nvidia-cublas]pti]3]
#     Found existing installation: cuda-bindings 12.9.437m╺━━━━━━━━━━━━━━━ 12/20 [nvidia-cublas]
#     Uninstalling cuda-bindings-12.9.4:━━━╺━━━━━━━━━━━━━━━ 12/20 [nvidia-cublas]
#       Successfully uninstalled cuda-bindings-12.9.4╺━━━━━━━━━━━━━ 13/20 [cuda-bindings]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [torchdata] 19/20 [torchdata]olver]3]
# Successfully installed cuda-bindings-13.2.0 cuda-toolkit-13.0.2 nvidia-cublas-13.1.0.3 nvidia-cuda-cupti-13.0.85 nvidia-cuda-nvrtc-13.0.88 nvidia-cuda-runtime-13.0.96 nvidia-cudnn-cu13-9.19.0.56 nvidia-cufft-12.0.0.61 nvidia-cufile-1.15.1.6 nvidia-curand-10.4.0.35 nvidia-cusolver-12.0.4.66 nvidia-cusparse-12.6.3.3 nvidia-cusparselt-cu13-0.8.0 nvidia-nccl-cu13-2.28.9 nvidia-nvjitlink-13.0.88 nvidia-nvshmem-cu13-3.4.5 nvidia-nvtx-13.0.85 setuptools-81.0.0 torch-2.11.0 torchdata-0.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dgl -f https://data.dgl.ai/wheels/torch-2.1/repo.html
# Out:
# Looking in links: https://data.dgl.ai/wheels/torch-2.1/repo.html
# Collecting dgl
#   Using cached dgl-0.1.3-py3-none-manylinux1_x86_64.whl.metadata (497 bytes)
# Requirement already satisfied: numpy>=1.14.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from dgl) (2.4.2)
# Requirement already satisfied: scipy>=1.1.0 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from dgl) (1.17.1)
# Requirement already satisfied: networkx>=2.1 in /home/joao/Desktop/MEI/SmarTaskUA/.venv/lib64/python3.13/site-packages (from dgl) (3.6.1)
# Using cached dgl-0.1.3-py3-none-manylinux1_x86_64.whl (409 kB)
# Installing collected packages: dgl
# Successfully installed dgl-0.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "numpy<2.0.0"
# Out:
# Collecting numpy<2.0.0
#   Downloading numpy-1.26.4.tar.gz (15.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 8.1 MB/s  0:00:02 eta 0:00:010:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: numpy
#   Building wheel for numpy (pyproject.toml) ... done
#   Created wheel for numpy: filename=numpy-1.26.4-cp313-cp313-linux_x86_64.whl size=9179637 sha256=60768eda302d29521a1bfe8a6f497fe65d188fc0adf510e881ce5d1b60e7b71e
#   Stored in directory: /home/joao/.cache/pip/wheels/8b/2d/9f/b6b46373f328e2ef50388915d351ccacbedac929459b5459bf
# Successfully built numpy
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.2
#     Uninstalling numpy-2.4.2:
#       Successfully uninstalled numpy-2.4.2
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install holidays
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting holidays
#   Downloading holidays-0.93-py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in /home/joao/.local/lib/python3.11/site-packages (from holidays) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/joao/.local/lib/python3.11/site-packages (from python-dateutil<3,>=2.9.0.post0->holidays) (1.17.0)
# Downloading holidays-0.93-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.0 MB/s eta 0:00:001.9 MB/s eta 0:00:01
# Installing collected packages: holidays
# Successfully installed holidays-0.93
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from typing import Optional
import datetime
import json
import numpy as np
import pandas as pd
import gymnasium as gym
from pathlib import Path

ACTION_TO_SHIFT_TEAM = {1: ("M", "A"), 2: ("T", "A"), 3: ("M", "B"), 4: ("T", "B")}
ACTION_SHIFT_ORDER = {0: 0, 1: 1, 2: 2, 3: 1, 4: 2}


def _build_special_days(year, n_days):
    import holidays as hl
    pt_holidays = hl.country_holidays("PT", years=[year])
    start = datetime.date(year, 1, 1)
    special = set()
    for d in range(n_days):
        date = start + datetime.timedelta(days=d)
        if date.weekday() == 6 or date in pt_holidays:
            special.add(d)
    return special


class ScheduleEnv(gym.Env):
    NUM_ACTIONS = 5

    def __init__(self, data_dir: str = "../../../data/problems/SMARTASK_SIMPLE_2025"):
        super().__init__()
        base = Path(data_dir)

        with open(base / "problem.json") as f:
            prob = json.load(f)

        self.num_days = prob["temporalScope"]["numDays"]
        self.year = prob["temporalScope"]["year"]
        employees = prob["employees"]["simple"]
        self.num_employees = len(employees)
        self.employee_teams = [set(emp.get("teams", [])) for emp in employees]

        vac_df = pd.read_csv(base / "vacations.csv", header=None)
        self.vac_mask = vac_df.iloc[:, 1:].values.astype(bool)

        dem_df = pd.read_csv(base / "demand.csv")
        dem_df["date"] = pd.to_datetime(dem_df["date"])
        start_ts = pd.Timestamp(f"{self.year}-01-01")
        dem_df["day_idx"] = (dem_df["date"] - start_ts).dt.days

        self.min_demand = np.zeros((self.num_days, 2, 2), dtype=int)
        _shift_idx = {"M": 0, "T": 1}
        _team_idx  = {"A": 0, "B": 1}
        for _, row in dem_df.iterrows():
            d = int(row["day_idx"])
            s = _shift_idx[row["shift"]]
            t = _team_idx[row["team"]]
            self.min_demand[d, s, t] = int(row["minimum"])

        self.special_days = _build_special_days(self.year, self.num_days)

        self.max_days_per_year = 223
        self.max_consecutive_days = 5
        self.special_days_cap = 22

        self.total_steps  = self.num_employees * self.num_days
        self.num_features = 2

        self.observation_space = gym.spaces.Box(
            low=-1.0, high=10.0,
            shape=(self.total_steps, self.num_features + self.NUM_ACTIONS),
            dtype=np.float32,
        )
        self.action_space = gym.spaces.Discrete(self.NUM_ACTIONS)
        self.reset()

    def _build_initial_matrix(self):
        """Sequential calendar-order day-major matrix."""
        matrix = np.zeros(
            (self.total_steps, self.num_features + self.NUM_ACTIONS), dtype=np.float32
        )
        self.emp_day_to_row = {}
        row = 0
        for day in range(self.num_days):
            for emp in range(self.num_employees):
                matrix[row, 0] = emp
                matrix[row, 1] = day
                self.emp_day_to_row[(emp, day)] = row
                row += 1
        return matrix

    def _row(self, emp, day):
        return self.emp_day_to_row[(emp, day)]

    def _get_prev_shift(self, emp, day):
        if day == 0:
            return None
        row = self.emp_day_to_row.get((emp, day - 1))
        if row is None:
            return None
        slot = self.state[row, 2:]
        if slot.sum() == 0 or slot[0] == 1:
            return None
        for a in range(1, self.NUM_ACTIONS):
            if slot[a] == 1:
                return ACTION_TO_SHIFT_TEAM[a][0]
        return None

    def _get_info(self):
        return {}

    def _calculate_reward(self, emp_id, day_id, action):
        remaining_days_in_year = self.num_days - day_id - 1
        remaining_budget = self.max_days_per_year - self.days_worked[emp_id]
        ideal_pace = self.max_days_per_year / self.num_days  # ~0.611
        reward = 0.0

        # How many days ahead/behind the linear schedule
        expected_worked = (day_id + 1) * ideal_pace
        ahead_by = self.days_worked[emp_id] - expected_worked

        if action != 0:
            shift, team = ACTION_TO_SHIFT_TEAM[action]
            s = 0 if shift == "M" else 1
            t = 0 if team  == "A" else 1
            cov = self.daily_coverage[day_id, s, t]
            mn = self.min_demand[day_id, s, t]

            if cov <= mn:
                reward += 2.0
            else:
                reward -= 1.0

            # Proportional pacing penalty when ahead of schedule
            if ahead_by > 3:
                reward -= min(2.0, 0.3 * (ahead_by - 3))

        else:
            # REST
            day_shortfall = np.maximum(0, self.min_demand[day_id] - self.daily_coverage[day_id]).sum()

            if ahead_by > 2:
                # Ahead of pace: resting is good, save budget for later
                reward += min(1.0, 0.25 * (ahead_by - 2))
            elif day_shortfall > 0 and remaining_budget > 0:
                # Behind pace with unmet demand: resting is bad
                if remaining_days_in_year > 0:
                    pace = remaining_budget / remaining_days_in_year
                    if pace >= ideal_pace:
                        reward -= 1.5

        # End-of-day signal after last employee on this day
        is_last_emp_today = (
            self.current_step >= self.total_steps or
            int(self.state[self.current_step, 1]) != day_id
        )
        if is_last_emp_today:
            day_shortfall = np.maximum(0, self.min_demand[day_id] - self.daily_coverage[day_id]).sum()
            if day_shortfall == 0:
                reward += 3.0
            else:
                reward -= day_shortfall * 2.0

        return reward

    def _calculate_final_reward(self):
        reward = 0.0
        total_shortfall = 0
        for day in range(self.num_days):
            for s in range(2):
                for t in range(2):
                    shortfall = self.min_demand[day, s, t] - self.daily_coverage[day, s, t]
                    if shortfall > 0:
                        total_shortfall += shortfall
        reward -= total_shortfall * 5.0

        for emp in range(self.num_employees):
            miss = self.max_days_per_year - self.days_worked[emp]
            if miss > 0:
                reward -= miss * 3.0

        if total_shortfall == 0:
            reward += 500.0
        return reward

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = self._build_initial_matrix()
        self.current_step = 0
        self.days_worked = np.zeros(self.num_employees, dtype=int)
        self.consecutive_days = np.zeros(self.num_employees, dtype=int)
        self.special_days_worked = np.zeros(self.num_employees, dtype=int)
        self.daily_coverage = np.zeros((self.num_days, 2, 2), dtype=np.float32)
        return self.state, self._get_info()

    def step(self, action):
        emp_id = int(self.state[self.current_step, 0])
        day_id = int(self.state[self.current_step, 1])

        self.state[self.current_step, 2 + action] = 1

        if action == 0:
            self.consecutive_days[emp_id] = 0
        else:
            self.days_worked[emp_id] += 1
            self.consecutive_days[emp_id] += 1
            shift, team = ACTION_TO_SHIFT_TEAM[action]
            s = 0 if shift == "M" else 1
            t = 0 if team == "A" else 1
            self.daily_coverage[day_id, s, t] += 1
            if day_id in self.special_days:
                self.special_days_worked[emp_id] += 1

        self.current_step += 1
        reward = self._calculate_reward(emp_id, day_id, action)

        terminated = self.current_step >= self.total_steps
        if terminated:
            reward += self._calculate_final_reward()

        return self.state.copy(), reward, terminated, False, self._get_info()

    def get_action_mask(self):
        if self.current_step >= self.total_steps:
            return np.array([True, False, False, False, False])

        emp = int(self.state[self.current_step, 0])
        day = int(self.state[self.current_step, 1])
        mask = np.ones(self.NUM_ACTIONS, dtype=bool)

        if self.vac_mask[emp, day]:
            mask[1:] = False
            return mask

        if self.days_worked[emp] >= self.max_days_per_year:
            mask[1:] = False
        elif self.consecutive_days[emp] >= self.max_consecutive_days:
            mask[1:] = False
        else:
            if day in self.special_days and self.special_days_worked[emp] >= self.special_days_cap:
                mask[1:] = False

            prev_shift = self._get_prev_shift(emp, day)
            if prev_shift == "T":
                mask[1] = False
                mask[3] = False

            for action, (_, team) in ACTION_TO_SHIFT_TEAM.items():
                if team not in self.employee_teams[emp]:
                    mask[action] = False

        if not np.any(mask):
            mask[0] = True
        return mask

    def render(self):
        labels = {0: "-", 1: "M-A", 2: "T-A", 3: "M-B", 4: "T-B"}
        for emp in range(self.num_employees):
            schedule = []
            for day in range(self.num_days):
                r = self.state[self._row(emp, day), 2:]
                schedule.append(labels[int(np.argmax(r))] if r.sum() > 0 else "-")
            print(f"Employee {emp + 1:2d}: {schedule}")

# %%
import dgl
import torch
import numpy as np


def build_graph(env):
    sources = env.state[:, 0].astype(np.int64)
    destinations = env.state[:, 1].astype(np.int64)
    graph_data = {
        ("employee", "assigned_to", "day"): (torch.tensor(sources), torch.tensor(destinations)),
        ("day", "staffed_by", "employee"): (torch.tensor(destinations), torch.tensor(sources)),
    }
    g = dgl.heterograph(graph_data)
    update_graph_features(g, env)
    return g


def update_graph_features(g, env):
    # Employee features: [days_worked, consecutive_days]
    emp_feat = np.column_stack((env.days_worked, env.consecutive_days))

    # Day features: coverage per (shift, team) — M-A, T-A, M-B, T-B
    day_feat = np.column_stack((
        env.daily_coverage[:, 0, 0],   # M-A
        env.daily_coverage[:, 1, 0],   # T-A
        env.daily_coverage[:, 0, 1],   # M-B
        env.daily_coverage[:, 1, 1],   # T-B
    ))

    g.nodes["employee"].data["feat"] = torch.tensor(emp_feat, dtype=torch.float32)
    g.nodes["day"].data["feat"] = torch.tensor(day_feat, dtype=torch.float32)

    # Edge features: one-hot action assignment (5 actions)
    edge_attr = env.state[:, 2:2 + env.NUM_ACTIONS]
    g.edges["assigned_to"].data["feat"] = torch.tensor(edge_attr, dtype=torch.float32)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


def build_day_features(env):
    """Build a (num_days, 6) tensor of structural day features."""
    max_demand = max(env.min_demand.max(), 1)
    feats = []
    for d in range(env.num_days):
        feats.append([
            env.min_demand[d, 0, 0] / max_demand,
            env.min_demand[d, 1, 0] / max_demand,
            env.min_demand[d, 0, 1] / max_demand,
            env.min_demand[d, 1, 1] / max_demand,
            float(d in env.special_days),
            d / env.num_days,
        ])
    return torch.tensor(feats, dtype=torch.float32)


class MLPActorCritic(nn.Module):
    """
    MLP Actor-Critic for PPO + GAE.
    Input per step: emp_emb + day_feat + cov_gap(4) + dyn_feats(3).
    dyn_feats = [days_worked, consecutive_days, pace_ratio].
    pace_ratio = remaining_budget / remaining_calendar_days.
    """
    DAY_FEAT_DIM = 6

    def __init__(self, num_employees, day_features, num_actions=5, emb_dim=16, hidden_dim=128):
        super().__init__()
        self.num_days = day_features.shape[0]

        self.emp_emb = nn.Embedding(num_employees, emb_dim)
        self.register_buffer("day_feat_table", day_features)
        self.day_proj = nn.Linear(self.DAY_FEAT_DIM, emb_dim)

        in_dim = emb_dim * 2 + 4 + 3 
        
        self.shared = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.Tanh(),
        )
        self.actor_head = nn.Sequential(
            nn.Linear(hidden_dim, 64),
            nn.Tanh(),
            nn.Linear(64, num_actions),
        )
        self.critic_head = nn.Sequential(
            nn.Linear(hidden_dim, 64),
            nn.Tanh(),
            nn.Linear(64, 1),
        )

    def _process_inputs(self, emp_ids, day_ids, cov_gaps, dyn_feats):
        e_emb = self.emp_emb(emp_ids)
        d_emb = self.day_proj(self.day_feat_table[day_ids])

        norm_dyn = dyn_feats.clone()
        norm_dyn[..., 0] /= 223.0
        norm_dyn[..., 1] /= 5.0

        return torch.cat([e_emb, d_emb, cov_gaps, norm_dyn], dim=-1)

    def forward(self, emp_ids, day_ids, cov_gaps, dyn_feats, action_masks):
        x = self._process_inputs(emp_ids, day_ids, cov_gaps, dyn_feats)
        shared_feat = self.shared(x)

        values = self.critic_head(shared_feat).squeeze(-1)

        logits = self.actor_head(shared_feat)
        masks_bool = torch.as_tensor(action_masks, dtype=torch.bool)
        if not masks_bool.any():
            masks_bool[..., 0] = True
        logits = logits.masked_fill(~masks_bool, float("-inf"))
        probs  = F.softmax(logits, dim=-1)

        return probs, values

# %%
from dataclasses import dataclass, field
from torch.distributions import Categorical

@dataclass
class Trajectory:
    emp_ids: list = field(default_factory=list)
    day_ids: list = field(default_factory=list)
    coverage_gaps: list = field(default_factory=list)
    dyn_emp_feats: list = field(default_factory=list)
    action_masks: list = field(default_factory=list)
    actions: list = field(default_factory=list)
    log_probs_old: list = field(default_factory=list)
    rewards: list = field(default_factory=list)
    values: list = field(default_factory=list)

    def to_tensors(self):
        return {
            "emp_ids": torch.tensor(self.emp_ids, dtype=torch.long),
            "day_ids": torch.tensor(self.day_ids, dtype=torch.long),
            "coverage_gaps": torch.stack(self.coverage_gaps),
            "dyn_emp_feats": torch.stack(self.dyn_emp_feats),
            "action_masks": torch.stack(self.action_masks),
            "actions": torch.tensor(self.actions, dtype=torch.long), # Chosen action
            "log_probs_old": torch.tensor(self.log_probs_old, dtype=torch.float32), # Log probs of that choice under the current policy
            "rewards": torch.tensor(self.rewards, dtype=torch.float32),
            "values": torch.tensor(self.values, dtype=torch.float32), # Critic value estimates
        } # Converted to tensors for batch training

def collect_trajectory(env, model):
    model.eval()
    traj = Trajectory()
    env.reset()
    terminated = truncated = False

    with torch.no_grad():
        while not (terminated or truncated):
            emp_id = int(env.state[env.current_step, 0])
            day_id = int(env.state[env.current_step, 1])

            cov_gap = [
                env.min_demand[day_id, 0, 0] - env.daily_coverage[day_id, 0, 0],
                env.min_demand[day_id, 1, 0] - env.daily_coverage[day_id, 1, 0],
                env.min_demand[day_id, 0, 1] - env.daily_coverage[day_id, 0, 1],
                env.min_demand[day_id, 1, 1] - env.daily_coverage[day_id, 1, 1],
            ]

            remaining_budget = env.max_days_per_year - env.days_worked[emp_id]
            remaining_cal = max(1, env.num_days - day_id)
            pace_ratio = remaining_budget / remaining_cal

            dyn_feat = [env.days_worked[emp_id], env.consecutive_days[emp_id], pace_ratio]
            action_mask = env.get_action_mask()

            emp_id_t = torch.tensor([emp_id], dtype=torch.long)
            day_id_t = torch.tensor([day_id], dtype=torch.long)
            cov_gap_t = torch.tensor([cov_gap], dtype=torch.float32)
            dyn_feat_t = torch.tensor([dyn_feat], dtype=torch.float32)
            mask_t = torch.tensor(action_mask.tolist(), dtype=torch.bool).unsqueeze(0)

            probs, values = model(emp_id_t, day_id_t, cov_gap_t, dyn_feat_t, mask_t)

            dist = Categorical(probs=probs[0])
            action = dist.sample()

            _, reward, terminated, truncated, _ = env.step(action.item())

            traj.emp_ids.append(emp_id)
            traj.day_ids.append(day_id)
            traj.coverage_gaps.append(cov_gap_t[0])
            traj.dyn_emp_feats.append(dyn_feat_t[0])
            traj.action_masks.append(mask_t[0])
            traj.actions.append(action.item())
            traj.log_probs_old.append(dist.log_prob(action).item())
            traj.rewards.append(float(reward))
            traj.values.append(values[0].item())

    return traj

# %%
def compute_gae(rewards, values, gamma=1.0, lam=0.95):
    T = len(rewards)
    rewards_a = np.array(rewards, dtype=np.float32)
    values_a = np.array(values,  dtype=np.float32)
    values_ext = np.append(values_a, 0.0)

    advantages = np.zeros(T, dtype=np.float32)
    gae = 0.0
    for t in reversed(range(T)):
        delta = rewards_a[t] + gamma * values_ext[t + 1] - values_ext[t]
        gae = delta + gamma * lam * gae
        advantages[t] = gae

    returns = advantages + values_a
    advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-5)

    return (
        torch.tensor(advantages, dtype=torch.float32),
        torch.tensor(returns, dtype=torch.float32),
    )

# %%
from torch.utils.data.sampler import BatchSampler, SubsetRandomSampler


def ppo_update(model, optimizer, batch, advantages, returns, clip_eps=0.2, value_coeff=0.5, entropy_coeff=0.01, K_epochs=4, mini_batch_size=512):
    T = batch["actions"].shape[0]
    losses = []
    track_entropy = []
    model.train()

    for _ in range(K_epochs):
        for index in BatchSampler(SubsetRandomSampler(range(T)), mini_batch_size, False):
            idx = torch.tensor(index)

            probs_new, values_new = model(
                batch["emp_ids"][idx],
                batch["day_ids"][idx],
                batch["coverage_gaps"][idx],
                batch["dyn_emp_feats"][idx],
                batch["action_masks"][idx],
            )

            dist_now = Categorical(probs=probs_new)
            a_logprob_now = dist_now.log_prob(batch["actions"][idx])
            dist_entropy = dist_now.entropy()

            ratios = torch.exp(a_logprob_now - batch["log_probs_old"][idx])
            adv = advantages[idx]
            surr1 = ratios * adv
            surr2 = torch.clamp(ratios, 1.0 - clip_eps, 1.0 + clip_eps) * adv
            actor_loss = -torch.min(surr1, surr2).mean() - entropy_coeff * dist_entropy.mean()

            critic_loss = F.smooth_l1_loss(values_new, returns[idx])

            loss = actor_loss + value_coeff * critic_loss

            track_entropy.append(dist_entropy.mean().item())

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
            optimizer.step()
            losses.append(loss.item())

    return float(np.mean(losses)), float(np.mean(track_entropy))

# %%
import os

# Hyperparameters
NUM_EPISODES = 10000
GAMMA = 1.0
LAM = 0.95
CLIP_EPS = 0.2
VALUE_COEFF = 0.5
ENTROPY_COEFF_0 = 0.02
ENTROPY_MIN = 0.002
K_EPOCHS = 4
MINI_BATCH_SIZE = 512
LR = 3e-4
SAVE_EVERY = 50

RESUME_FROM = None

env = ScheduleEnv()
day_features = build_day_features(env)
model = MLPActorCritic(num_employees=env.num_employees, day_features=day_features)
optimizer = torch.optim.Adam(model.parameters(), lr=LR, eps=1e-5)

best_reward = -float("inf")
start_episode = 0

if RESUME_FROM and os.path.exists(RESUME_FROM):
    ckpt = torch.load(RESUME_FROM, weights_only=True)
    model.load_state_dict(ckpt["model_state_dict"])
    optimizer.load_state_dict(ckpt["optimizer_state_dict"])
    start_episode = ckpt["episode"]
    best_reward = float(ckpt.get("best_reward", -float("inf")))
    print(f"Resumed from episode {start_episode}, best reward = {best_reward:.1f}")

for episode in range(start_episode, NUM_EPISODES):
    entropy_coeff = max(ENTROPY_MIN, ENTROPY_COEFF_0 * (0.998 ** episode))

    traj = collect_trajectory(env, model)
    batch = traj.to_tensors()

    advantages, returns = compute_gae(traj.rewards, traj.values, GAMMA, LAM)

    mean_loss, mean_entropy = ppo_update(
        model, optimizer, batch, advantages, returns,
        clip_eps=CLIP_EPS,
        value_coeff=VALUE_COEFF,
        entropy_coeff=entropy_coeff,
        K_epochs=K_EPOCHS,
        mini_batch_size=MINI_BATCH_SIZE,
    )

    total_reward = sum(traj.rewards)

    if total_reward > best_reward:
        best_reward = float(total_reward)
        torch.save(
            {"episode": episode, "model_state_dict": model.state_dict(),
             "optimizer_state_dict": optimizer.state_dict(), "best_reward": best_reward},
            "best_ppo_scheduler_v2.pth",
        )
        print(f"  NEW BEST: {best_reward:.1f} at episode {episode}")

    if episode % 10 == 0:
        shortfall = int(np.maximum(0, env.min_demand - env.daily_coverage).sum())
        print(f"Ep {episode:>4} | R={total_reward:>8.1f} | Best={best_reward:>8.1f} "
              f"| Loss={mean_loss:.4f} | ent={mean_entropy:.4f} | ent_coeff={entropy_coeff:.4f} "
              f"| shortfall={shortfall}")

    if (episode + 1) % SAVE_EVERY == 0:
        torch.save(
            {"episode": episode + 1, "model_state_dict": model.state_dict(),
             "optimizer_state_dict": optimizer.state_dict(), "best_reward": best_reward},
            "latest_ppo_scheduler_v2.pth",
        )
# Out:
#   NEW BEST: -4844.9 at episode 0
# Ep    0 | R= -4844.9 | Best= -4844.9 | Loss=11.2908 | ent=0.8651 | ent_coeff=0.0200 | shortfall=547
#   NEW BEST: -4122.9 at episode 1
#   NEW BEST: -3964.4 at episode 2
# Ep   10 | R= -4160.7 | Best= -3964.4 | Loss=10.1124 | ent=0.8581 | ent_coeff=0.0196 | shortfall=505
#   NEW BEST: -3871.7 at episode 11
#   NEW BEST: -2839.4 at episode 12
#   NEW BEST: -2821.7 at episode 14
#   NEW BEST: -2698.5 at episode 15
#   NEW BEST: -2686.3 at episode 17
# Ep   20 | R= -4485.1 | Best= -2686.3 | Loss=10.3543 | ent=0.8502 | ent_coeff=0.0192 | shortfall=525
# Ep   30 | R= -6975.0 | Best= -2686.3 | Loss=15.9283 | ent=0.9074 | ent_coeff=0.0188 | shortfall=645
# Ep   40 | R= -4498.4 | Best= -2686.3 | Loss=10.5516 | ent=0.8386 | ent_coeff=0.0185 | shortfall=545
# Ep   50 | R= -3570.7 | Best= -2686.3 | Loss=8.9354 | ent=0.8020 | ent_coeff=0.0181 | shortfall=493
# Ep   60 | R= -3306.9 | Best= -2686.3 | Loss=8.4514 | ent=0.8140 | ent_coeff=0.0177 | shortfall=449
# Ep   70 | R= -6788.7 | Best= -2686.3 | Loss=14.7699 | ent=0.8871 | ent_coeff=0.0174 | shortfall=648
# Ep   80 | R= -5002.0 | Best= -2686.3 | Loss=11.3692 | ent=0.8589 | ent_coeff=0.0170 | shortfall=568
# Ep   90 | R= -3337.5 | Best= -2686.3 | Loss=8.4849 | ent=0.8229 | ent_coeff=0.0167 | shortfall=458
# Ep  100 | R= -4501.3 | Best= -2686.3 | Loss=10.5152 | ent=0.8743 | ent_coeff=0.0164 | shortfall=510
# Ep  110 | R= -4189.3 | Best= -2686.3 | Loss=10.0104 | ent=0.8524 | ent_coeff=0.0160 | shortfall=508
# Ep  120 | R= -4682.0 | Best= -2686.3 | Loss=10.9588 | ent=0.8683 | ent_coeff=0.0157 | shortfall=533
# Ep  130 | R= -5712.1 | Best= -2686.3 | Loss=13.0281 | ent=0.8924 | ent_coeff=0.0154 | shortfall=574
# Ep  140 | R= -6116.6 | Best= -2686.3 | Loss=13.4998 | ent=0.8832 | ent_coeff=0.0151 | shortfall=615
# Ep  150 | R= -5872.7 | Best= -2686.3 | Loss=13.2787 | ent=0.9061 | ent_coeff=0.0148 | shortfall=570
#   NEW BEST: -2646.7 at episode 160
# Ep  160 | R= -2646.7 | Best= -2646.7 | Loss=7.0879 | ent=0.7540 | ent_coeff=0.0145 | shortfall=443
# Ep  170 | R= -3669.6 | Best= -2646.7 | Loss=9.0583 | ent=0.7994 | ent_coeff=0.0142 | shortfall=488
# Ep  180 | R= -5503.5 | Best= -2646.7 | Loss=12.4113 | ent=0.8563 | ent_coeff=0.0139 | shortfall=578
# Ep  190 | R= -5238.3 | Best= -2646.7 | Loss=11.8956 | ent=0.8856 | ent_coeff=0.0137 | shortfall=552
# Ep  200 | R= -4212.9 | Best= -2646.7 | Loss=10.1818 | ent=0.8714 | ent_coeff=0.0134 | shortfall=494
# Ep  210 | R= -5059.1 | Best= -2646.7 | Loss=11.3836 | ent=0.8445 | ent_coeff=0.0131 | shortfall=573
# Ep  220 | R= -4511.6 | Best= -2646.7 | Loss=10.2178 | ent=0.8769 | ent_coeff=0.0129 | shortfall=543
# Ep  230 | R= -2896.8 | Best= -2646.7 | Loss=7.3930 | ent=0.7191 | ent_coeff=0.0126 | shortfall=465
# Ep  240 | R= -3282.2 | Best= -2646.7 | Loss=7.8494 | ent=0.7729 | ent_coeff=0.0124 | shortfall=459
# Ep  250 | R= -6107.2 | Best= -2646.7 | Loss=13.5452 | ent=0.8988 | ent_coeff=0.0121 | shortfall=598
# Ep  260 | R= -4217.3 | Best= -2646.7 | Loss=9.5803 | ent=0.8727 | ent_coeff=0.0119 | shortfall=508
# Ep  270 | R= -4184.6 | Best= -2646.7 | Loss=9.5287 | ent=0.8663 | ent_coeff=0.0116 | shortfall=491
#   NEW BEST: -2533.6 at episode 275
# Ep  280 | R= -3583.3 | Best= -2533.6 | Loss=8.5382 | ent=0.8006 | ent_coeff=0.0114 | shortfall=482
#   NEW BEST: -2464.8 at episode 282
# Ep  290 | R= -3960.4 | Best= -2464.8 | Loss=9.4425 | ent=0.8785 | ent_coeff=0.0112 | shortfall=490
# Ep  300 | R= -3583.2 | Best= -2464.8 | Loss=8.5459 | ent=0.7283 | ent_coeff=0.0110 | shortfall=517
# Ep  310 | R= -3686.0 | Best= -2464.8 | Loss=8.2825 | ent=0.7341 | ent_coeff=0.0108 | shortfall=522
# Ep  320 | R= -3118.1 | Best= -2464.8 | Loss=7.7940 | ent=0.8020 | ent_coeff=0.0105 | shortfall=454
# Ep  330 | R= -4613.7 | Best= -2464.8 | Loss=10.1342 | ent=0.7689 | ent_coeff=0.0103 | shortfall=582
# Ep  340 | R= -3399.2 | Best= -2464.8 | Loss=7.9171 | ent=0.7776 | ent_coeff=0.0101 | shortfall=487
# Ep  350 | R= -2927.2 | Best= -2464.8 | Loss=7.5651 | ent=0.7111 | ent_coeff=0.0099 | shortfall=459
# Ep  360 | R= -4200.8 | Best= -2464.8 | Loss=9.3646 | ent=0.7995 | ent_coeff=0.0097 | shortfall=512
# Ep  370 | R= -3236.7 | Best= -2464.8 | Loss=7.9219 | ent=0.8269 | ent_coeff=0.0095 | shortfall=454
#   NEW BEST: -2277.1 at episode 377
# Ep  380 | R= -2851.8 | Best= -2277.1 | Loss=7.5095 | ent=0.7482 | ent_coeff=0.0093 | shortfall=464
# Ep  390 | R= -3576.6 | Best= -2277.1 | Loss=8.1524 | ent=0.8125 | ent_coeff=0.0092 | shortfall=469
# Ep  400 | R= -3992.9 | Best= -2277.1 | Loss=8.7271 | ent=0.8537 | ent_coeff=0.0090 | shortfall=481
# Ep  410 | R= -4009.6 | Best= -2277.1 | Loss=8.8060 | ent=0.8374 | ent_coeff=0.0088 | shortfall=500
# Ep  420 | R= -3665.3 | Best= -2277.1 | Loss=8.7753 | ent=0.8486 | ent_coeff=0.0086 | shortfall=471
# Ep  430 | R= -5491.2 | Best= -2277.1 | Loss=11.5915 | ent=0.8690 | ent_coeff=0.0085 | shortfall=590
# Ep  440 | R= -5574.4 | Best= -2277.1 | Loss=12.0495 | ent=0.7962 | ent_coeff=0.0083 | shortfall=661
# Ep  450 | R= -5568.1 | Best= -2277.1 | Loss=11.8696 | ent=0.8221 | ent_coeff=0.0081 | shortfall=636
# Ep  460 | R= -4199.1 | Best= -2277.1 | Loss=9.4990 | ent=0.8876 | ent_coeff=0.0080 | shortfall=479
# Ep  470 | R= -3439.1 | Best= -2277.1 | Loss=7.9446 | ent=0.7885 | ent_coeff=0.0078 | shortfall=490
# Ep  480 | R= -4976.6 | Best= -2277.1 | Loss=10.7269 | ent=0.8983 | ent_coeff=0.0077 | shortfall=533
# Ep  490 | R= -3774.9 | Best= -2277.1 | Loss=8.5909 | ent=0.8011 | ent_coeff=0.0075 | shortfall=498
# Ep  500 | R= -3493.2 | Best= -2277.1 | Loss=8.0260 | ent=0.7641 | ent_coeff=0.0074 | shortfall=464
# Ep  510 | R= -3994.1 | Best= -2277.1 | Loss=9.0098 | ent=0.7899 | ent_coeff=0.0072 | shortfall=502
# Ep  520 | R= -2985.5 | Best= -2277.1 | Loss=7.1190 | ent=0.7624 | ent_coeff=0.0071 | shortfall=445
#   NEW BEST: -2168.1 at episode 521
# Ep  530 | R= -3410.0 | Best= -2168.1 | Loss=8.0173 | ent=0.7767 | ent_coeff=0.0069 | shortfall=462
# Ep  540 | R= -4121.9 | Best= -2168.1 | Loss=8.7834 | ent=0.8213 | ent_coeff=0.0068 | shortfall=482
# Ep  550 | R= -5131.5 | Best= -2168.1 | Loss=11.6090 | ent=0.8949 | ent_coeff=0.0067 | shortfall=535
# Ep  560 | R= -4743.0 | Best= -2168.1 | Loss=10.8615 | ent=0.8791 | ent_coeff=0.0065 | shortfall=515
# Ep  570 | R= -4099.8 | Best= -2168.1 | Loss=9.4214 | ent=0.8375 | ent_coeff=0.0064 | shortfall=529
# Ep  580 | R= -3231.9 | Best= -2168.1 | Loss=7.1735 | ent=0.7951 | ent_coeff=0.0063 | shortfall=472
# Ep  590 | R= -5133.9 | Best= -2168.1 | Loss=11.2897 | ent=0.8799 | ent_coeff=0.0061 | shortfall=530
# Ep  600 | R= -5147.5 | Best= -2168.1 | Loss=11.5887 | ent=0.8478 | ent_coeff=0.0060 | shortfall=560
# Ep  610 | R= -3405.7 | Best= -2168.1 | Loss=7.8481 | ent=0.8411 | ent_coeff=0.0059 | shortfall=451
# Ep  620 | R= -2946.2 | Best= -2168.1 | Loss=6.8405 | ent=0.7069 | ent_coeff=0.0058 | shortfall=438
# Ep  630 | R= -2851.2 | Best= -2168.1 | Loss=6.4477 | ent=0.7338 | ent_coeff=0.0057 | shortfall=438
# Ep  640 | R= -4286.9 | Best= -2168.1 | Loss=9.5430 | ent=0.8644 | ent_coeff=0.0056 | shortfall=482
# Ep  650 | R= -3303.8 | Best= -2168.1 | Loss=7.5966 | ent=0.7299 | ent_coeff=0.0054 | shortfall=501
# Ep  660 | R= -3224.8 | Best= -2168.1 | Loss=7.2264 | ent=0.7404 | ent_coeff=0.0053 | shortfall=465
# Ep  670 | R= -4686.0 | Best= -2168.1 | Loss=9.6666 | ent=0.7706 | ent_coeff=0.0052 | shortfall=593
# Ep  680 | R= -3126.3 | Best= -2168.1 | Loss=7.4783 | ent=0.8095 | ent_coeff=0.0051 | shortfall=457
# Ep  690 | R= -3387.1 | Best= -2168.1 | Loss=7.7447 | ent=0.8375 | ent_coeff=0.0050 | shortfall=436
# Ep  700 | R= -3068.6 | Best= -2168.1 | Loss=7.0796 | ent=0.7499 | ent_coeff=0.0049 | shortfall=448
# Ep  710 | R= -2854.3 | Best= -2168.1 | Loss=6.7339 | ent=0.7762 | ent_coeff=0.0048 | shortfall=437
# Ep  720 | R= -3882.6 | Best= -2168.1 | Loss=8.3941 | ent=0.8050 | ent_coeff=0.0047 | shortfall=516
# Ep  730 | R= -2822.3 | Best= -2168.1 | Loss=6.5368 | ent=0.7918 | ent_coeff=0.0046 | shortfall=411
# Ep  740 | R= -2981.5 | Best= -2168.1 | Loss=6.9876 | ent=0.7722 | ent_coeff=0.0045 | shortfall=436
# Ep  750 | R= -3778.1 | Best= -2168.1 | Loss=8.0249 | ent=0.7578 | ent_coeff=0.0045 | shortfall=503
# Ep  760 | R= -3359.8 | Best= -2168.1 | Loss=7.8506 | ent=0.8482 | ent_coeff=0.0044 | shortfall=454
# Ep  770 | R= -5420.2 | Best= -2168.1 | Loss=11.5503 | ent=0.8742 | ent_coeff=0.0043 | shortfall=556
# Ep  780 | R= -3268.9 | Best= -2168.1 | Loss=7.1617 | ent=0.7803 | ent_coeff=0.0042 | shortfall=469
# Ep  790 | R= -3538.7 | Best= -2168.1 | Loss=7.9302 | ent=0.8169 | ent_coeff=0.0041 | shortfall=468
# Ep  800 | R= -3489.2 | Best= -2168.1 | Loss=7.5485 | ent=0.8051 | ent_coeff=0.0040 | shortfall=470
# Ep  810 | R= -3807.0 | Best= -2168.1 | Loss=8.3767 | ent=0.8135 | ent_coeff=0.0040 | shortfall=491
# Ep  820 | R= -4883.0 | Best= -2168.1 | Loss=10.1971 | ent=0.8775 | ent_coeff=0.0039 | shortfall=530
# Ep  830 | R= -3123.8 | Best= -2168.1 | Loss=6.6331 | ent=0.7962 | ent_coeff=0.0038 | shortfall=453
# Ep  840 | R= -3225.7 | Best= -2168.1 | Loss=6.9738 | ent=0.7860 | ent_coeff=0.0037 | shortfall=470
# Ep  850 | R= -3019.8 | Best= -2168.1 | Loss=6.7401 | ent=0.7030 | ent_coeff=0.0036 | shortfall=463
# Ep  860 | R= -3473.3 | Best= -2168.1 | Loss=7.5878 | ent=0.8140 | ent_coeff=0.0036 | shortfall=479
# Ep  870 | R= -3374.5 | Best= -2168.1 | Loss=6.9921 | ent=0.8057 | ent_coeff=0.0035 | shortfall=445
# Ep  880 | R= -2355.8 | Best= -2168.1 | Loss=5.6557 | ent=0.7237 | ent_coeff=0.0034 | shortfall=422
# Ep  890 | R= -2569.3 | Best= -2168.1 | Loss=5.9751 | ent=0.7345 | ent_coeff=0.0034 | shortfall=434
# Ep  900 | R= -3296.1 | Best= -2168.1 | Loss=6.9936 | ent=0.8174 | ent_coeff=0.0033 | shortfall=449
# Ep  910 | R= -2222.9 | Best= -2168.1 | Loss=5.3998 | ent=0.7690 | ent_coeff=0.0032 | shortfall=396
# Ep  920 | R= -3571.2 | Best= -2168.1 | Loss=7.6503 | ent=0.7101 | ent_coeff=0.0032 | shortfall=502
# Ep  930 | R= -3406.8 | Best= -2168.1 | Loss=7.3151 | ent=0.7460 | ent_coeff=0.0031 | shortfall=496
# Ep  940 | R= -3693.5 | Best= -2168.1 | Loss=7.5780 | ent=0.8059 | ent_coeff=0.0030 | shortfall=474
# Ep  950 | R= -3111.5 | Best= -2168.1 | Loss=6.7342 | ent=0.7657 | ent_coeff=0.0030 | shortfall=432
#   NEW BEST: -2151.2 at episode 959
# Ep  960 | R= -2493.8 | Best= -2151.2 | Loss=5.5622 | ent=0.7698 | ent_coeff=0.0029 | shortfall=400
# Ep  970 | R= -3143.6 | Best= -2151.2 | Loss=6.6772 | ent=0.7789 | ent_coeff=0.0029 | shortfall=431
# Ep  980 | R= -2735.3 | Best= -2151.2 | Loss=6.1685 | ent=0.7623 | ent_coeff=0.0028 | shortfall=415
# Ep  990 | R= -2549.4 | Best= -2151.2 | Loss=5.5961 | ent=0.7400 | ent_coeff=0.0028 | shortfall=418
#   NEW BEST: -2003.0 at episode 996
# Ep 1000 | R= -2440.9 | Best= -2003.0 | Loss=5.1977 | ent=0.7122 | ent_coeff=0.0027 | shortfall=405
#   NEW BEST: -1888.6 at episode 1003
# Ep 1010 | R= -2699.1 | Best= -1888.6 | Loss=5.7793 | ent=0.7310 | ent_coeff=0.0026 | shortfall=418
# Ep 1020 | R= -2479.1 | Best= -1888.6 | Loss=5.4184 | ent=0.7123 | ent_coeff=0.0026 | shortfall=390
# Ep 1030 | R= -2223.2 | Best= -1888.6 | Loss=5.5059 | ent=0.7239 | ent_coeff=0.0025 | shortfall=375
# Ep 1040 | R= -4024.2 | Best= -1888.6 | Loss=8.7154 | ent=0.7964 | ent_coeff=0.0025 | shortfall=478
# Ep 1050 | R= -2524.8 | Best= -1888.6 | Loss=5.7859 | ent=0.7627 | ent_coeff=0.0024 | shortfall=399
# Ep 1060 | R= -4088.0 | Best= -1888.6 | Loss=8.8457 | ent=0.7781 | ent_coeff=0.0024 | shortfall=521
# Ep 1070 | R= -2844.3 | Best= -1888.6 | Loss=6.0935 | ent=0.6816 | ent_coeff=0.0023 | shortfall=440
# Ep 1080 | R= -2990.4 | Best= -1888.6 | Loss=6.2159 | ent=0.6982 | ent_coeff=0.0023 | shortfall=453
# Ep 1090 | R= -3077.8 | Best= -1888.6 | Loss=6.7770 | ent=0.7701 | ent_coeff=0.0023 | shortfall=403
# Ep 1100 | R= -1981.2 | Best= -1888.6 | Loss=4.7778 | ent=0.6414 | ent_coeff=0.0022 | shortfall=365
# Ep 1110 | R= -2703.9 | Best= -1888.6 | Loss=5.8324 | ent=0.6992 | ent_coeff=0.0022 | shortfall=401
# Ep 1120 | R= -2805.8 | Best= -1888.6 | Loss=5.7298 | ent=0.6701 | ent_coeff=0.0021 | shortfall=410
# Ep 1130 | R= -2891.2 | Best= -1888.6 | Loss=6.5591 | ent=0.7527 | ent_coeff=0.0021 | shortfall=409
# Ep 1140 | R= -3034.7 | Best= -1888.6 | Loss=6.1477 | ent=0.6863 | ent_coeff=0.0020 | shortfall=481
# Ep 1150 | R= -4418.6 | Best= -1888.6 | Loss=9.0339 | ent=0.7369 | ent_coeff=0.0020 | shortfall=482
# Ep 1160 | R= -2567.0 | Best= -1888.6 | Loss=5.6027 | ent=0.7106 | ent_coeff=0.0020 | shortfall=402
# Ep 1170 | R= -2648.0 | Best= -1888.6 | Loss=5.6477 | ent=0.6914 | ent_coeff=0.0020 | shortfall=380
# Ep 1180 | R= -2888.9 | Best= -1888.6 | Loss=5.9993 | ent=0.6794 | ent_coeff=0.0020 | shortfall=414
# Ep 1190 | R= -4004.8 | Best= -1888.6 | Loss=8.1010 | ent=0.7852 | ent_coeff=0.0020 | shortfall=451
# Ep 1200 | R= -2933.0 | Best= -1888.6 | Loss=6.2030 | ent=0.7265 | ent_coeff=0.0020 | shortfall=408
# Ep 1210 | R= -2929.3 | Best= -1888.6 | Loss=6.3137 | ent=0.7423 | ent_coeff=0.0020 | shortfall=406
# Ep 1220 | R= -2407.5 | Best= -1888.6 | Loss=5.4292 | ent=0.6636 | ent_coeff=0.0020 | shortfall=389
# Ep 1230 | R= -2405.3 | Best= -1888.6 | Loss=4.9367 | ent=0.6343 | ent_coeff=0.0020 | shortfall=391
# Ep 1240 | R= -2414.3 | Best= -1888.6 | Loss=4.9878 | ent=0.6506 | ent_coeff=0.0020 | shortfall=373
#   NEW BEST: -1796.1 at episode 1241
# Ep 1250 | R= -2006.7 | Best= -1796.1 | Loss=4.6929 | ent=0.6984 | ent_coeff=0.0020 | shortfall=358
#   NEW BEST: -1768.5 at episode 1252
# Ep 1260 | R= -2355.7 | Best= -1768.5 | Loss=5.0495 | ent=0.6619 | ent_coeff=0.0020 | shortfall=371
#   NEW BEST: -1642.5 at episode 1265
# Ep 1270 | R= -1892.5 | Best= -1642.5 | Loss=4.6491 | ent=0.6308 | ent_coeff=0.0020 | shortfall=370
# Ep 1280 | R= -2218.2 | Best= -1642.5 | Loss=4.6573 | ent=0.6829 | ent_coeff=0.0020 | shortfall=377
# Ep 1290 | R= -2382.7 | Best= -1642.5 | Loss=5.0883 | ent=0.6617 | ent_coeff=0.0020 | shortfall=396
# Ep 1300 | R= -2800.4 | Best= -1642.5 | Loss=6.1863 | ent=0.7425 | ent_coeff=0.0020 | shortfall=387
# Ep 1310 | R= -2495.2 | Best= -1642.5 | Loss=5.4714 | ent=0.7137 | ent_coeff=0.0020 | shortfall=391
# Ep 1320 | R= -2134.2 | Best= -1642.5 | Loss=4.5532 | ent=0.6749 | ent_coeff=0.0020 | shortfall=364
# Ep 1330 | R= -2641.3 | Best= -1642.5 | Loss=5.4420 | ent=0.7151 | ent_coeff=0.0020 | shortfall=380
# Ep 1340 | R= -3803.0 | Best= -1642.5 | Loss=7.5544 | ent=0.7379 | ent_coeff=0.0020 | shortfall=472
# Ep 1350 | R= -2192.6 | Best= -1642.5 | Loss=4.8309 | ent=0.6946 | ent_coeff=0.0020 | shortfall=355
# Ep 1360 | R= -1958.6 | Best= -1642.5 | Loss=4.5749 | ent=0.7147 | ent_coeff=0.0020 | shortfall=343
# Ep 1370 | R= -2487.1 | Best= -1642.5 | Loss=5.1792 | ent=0.6873 | ent_coeff=0.0020 | shortfall=386
# Ep 1380 | R= -2023.2 | Best= -1642.5 | Loss=4.3040 | ent=0.6282 | ent_coeff=0.0020 | shortfall=362
# Ep 1390 | R= -2525.4 | Best= -1642.5 | Loss=5.0590 | ent=0.6571 | ent_coeff=0.0020 | shortfall=376
# Ep 1400 | R= -2710.9 | Best= -1642.5 | Loss=5.3462 | ent=0.6683 | ent_coeff=0.0020 | shortfall=382
# Ep 1410 | R= -2975.7 | Best= -1642.5 | Loss=6.4506 | ent=0.7289 | ent_coeff=0.0020 | shortfall=395
# Ep 1420 | R= -2201.3 | Best= -1642.5 | Loss=4.8846 | ent=0.6913 | ent_coeff=0.0020 | shortfall=370
# Ep 1430 | R= -2348.1 | Best= -1642.5 | Loss=5.4561 | ent=0.7109 | ent_coeff=0.0020 | shortfall=379
# Ep 1440 | R= -2542.0 | Best= -1642.5 | Loss=5.3967 | ent=0.7319 | ent_coeff=0.0020 | shortfall=375
# Ep 1450 | R= -2433.2 | Best= -1642.5 | Loss=5.0968 | ent=0.6715 | ent_coeff=0.0020 | shortfall=368
# Ep 1460 | R= -2528.7 | Best= -1642.5 | Loss=5.1012 | ent=0.6499 | ent_coeff=0.0020 | shortfall=401
# Ep 1470 | R= -2741.6 | Best= -1642.5 | Loss=5.4068 | ent=0.6874 | ent_coeff=0.0020 | shortfall=416
# Ep 1480 | R= -5229.4 | Best= -1642.5 | Loss=10.6910 | ent=0.8003 | ent_coeff=0.0020 | shortfall=533
# Ep 1490 | R= -4517.5 | Best= -1642.5 | Loss=8.6749 | ent=0.6764 | ent_coeff=0.0020 | shortfall=559
# Ep 1500 | R= -2265.2 | Best= -1642.5 | Loss=4.5875 | ent=0.6450 | ent_coeff=0.0020 | shortfall=379
# Ep 1510 | R= -2985.1 | Best= -1642.5 | Loss=5.6081 | ent=0.6645 | ent_coeff=0.0020 | shortfall=421
# Ep 1520 | R= -1862.8 | Best= -1642.5 | Loss=4.1087 | ent=0.6844 | ent_coeff=0.0020 | shortfall=335
# Ep 1530 | R= -2474.0 | Best= -1642.5 | Loss=4.8640 | ent=0.7035 | ent_coeff=0.0020 | shortfall=350
# Ep 1540 | R= -2177.1 | Best= -1642.5 | Loss=4.4677 | ent=0.6716 | ent_coeff=0.0020 | shortfall=355
# Ep 1550 | R= -2160.4 | Best= -1642.5 | Loss=4.2369 | ent=0.6322 | ent_coeff=0.0020 | shortfall=360
# Ep 1560 | R= -2326.3 | Best= -1642.5 | Loss=4.7360 | ent=0.6332 | ent_coeff=0.0020 | shortfall=363
# Ep 1570 | R= -1891.7 | Best= -1642.5 | Loss=3.8320 | ent=0.6034 | ent_coeff=0.0020 | shortfall=337
# Ep 1580 | R= -2342.4 | Best= -1642.5 | Loss=4.7111 | ent=0.6581 | ent_coeff=0.0020 | shortfall=345
# Ep 1590 | R= -1697.5 | Best= -1642.5 | Loss=4.0894 | ent=0.6250 | ent_coeff=0.0020 | shortfall=328
# Ep 1600 | R= -2162.7 | Best= -1642.5 | Loss=4.2448 | ent=0.5895 | ent_coeff=0.0020 | shortfall=372
# Ep 1610 | R= -2493.8 | Best= -1642.5 | Loss=4.7484 | ent=0.6196 | ent_coeff=0.0020 | shortfall=380
# Ep 1620 | R= -1977.8 | Best= -1642.5 | Loss=4.0833 | ent=0.6415 | ent_coeff=0.0020 | shortfall=328
# Ep 1630 | R= -2498.1 | Best= -1642.5 | Loss=5.1326 | ent=0.6457 | ent_coeff=0.0020 | shortfall=369
# Ep 1640 | R= -1649.0 | Best= -1642.5 | Loss=3.9290 | ent=0.6178 | ent_coeff=0.0020 | shortfall=319
#   NEW BEST: -1611.5 at episode 1642
# Ep 1650 | R= -2133.9 | Best= -1611.5 | Loss=4.1157 | ent=0.6572 | ent_coeff=0.0020 | shortfall=325
# Ep 1660 | R= -5866.7 | Best= -1611.5 | Loss=12.0427 | ent=0.8113 | ent_coeff=0.0020 | shortfall=547
# Ep 1670 | R= -3656.1 | Best= -1611.5 | Loss=7.1926 | ent=0.7699 | ent_coeff=0.0020 | shortfall=423
# Ep 1680 | R= -7726.8 | Best= -1611.5 | Loss=15.4010 | ent=0.7283 | ent_coeff=0.0020 | shortfall=687
# Ep 1690 | R= -9311.8 | Best= -1611.5 | Loss=18.6582 | ent=0.7385 | ent_coeff=0.0020 | shortfall=803
# Ep 1700 | R= -8430.4 | Best= -1611.5 | Loss=17.2177 | ent=0.7509 | ent_coeff=0.0020 | shortfall=742
# Ep 1710 | R= -5248.0 | Best= -1611.5 | Loss=10.3177 | ent=0.7651 | ent_coeff=0.0020 | shortfall=560
# Ep 1720 | R= -4781.7 | Best= -1611.5 | Loss=9.1044 | ent=0.7569 | ent_coeff=0.0020 | shortfall=502
# Ep 1730 | R= -3187.3 | Best= -1611.5 | Loss=6.4128 | ent=0.7510 | ent_coeff=0.0020 | shortfall=418
# Ep 1740 | R= -2180.1 | Best= -1611.5 | Loss=4.6433 | ent=0.7061 | ent_coeff=0.0020 | shortfall=353
# Ep 1750 | R= -2535.4 | Best= -1611.5 | Loss=4.7731 | ent=0.6470 | ent_coeff=0.0020 | shortfall=392
# Ep 1760 | R= -3073.9 | Best= -1611.5 | Loss=5.9915 | ent=0.6969 | ent_coeff=0.0020 | shortfall=425
# Ep 1770 | R= -2590.4 | Best= -1611.5 | Loss=5.0602 | ent=0.7195 | ent_coeff=0.0020 | shortfall=369
#   NEW BEST: -1593.6 at episode 1774
# Ep 1780 | R= -2210.4 | Best= -1593.6 | Loss=4.3756 | ent=0.6495 | ent_coeff=0.0020 | shortfall=357
# Ep 1790 | R= -2107.4 | Best= -1593.6 | Loss=4.0052 | ent=0.6403 | ent_coeff=0.0020 | shortfall=362
# Ep 1800 | R= -1992.1 | Best= -1593.6 | Loss=3.9563 | ent=0.6536 | ent_coeff=0.0020 | shortfall=341
# Ep 1810 | R= -2538.1 | Best= -1593.6 | Loss=4.8843 | ent=0.6512 | ent_coeff=0.0020 | shortfall=370
# Ep 1820 | R= -2196.2 | Best= -1593.6 | Loss=4.7263 | ent=0.7176 | ent_coeff=0.0020 | shortfall=355
# Ep 1830 | R= -2755.8 | Best= -1593.6 | Loss=5.6504 | ent=0.7426 | ent_coeff=0.0020 | shortfall=374
# Ep 1840 | R= -1761.8 | Best= -1593.6 | Loss=3.3303 | ent=0.6336 | ent_coeff=0.0020 | shortfall=322
# Ep 1850 | R= -2339.0 | Best= -1593.6 | Loss=4.2960 | ent=0.6465 | ent_coeff=0.0020 | shortfall=361
# Ep 1860 | R= -2173.0 | Best= -1593.6 | Loss=4.0316 | ent=0.6239 | ent_coeff=0.0020 | shortfall=361
# Ep 1870 | R= -2318.6 | Best= -1593.6 | Loss=4.4349 | ent=0.6419 | ent_coeff=0.0020 | shortfall=351
# Ep 1880 | R= -2073.7 | Best= -1593.6 | Loss=4.1370 | ent=0.6603 | ent_coeff=0.0020 | shortfall=342
#   NEW BEST: -1509.4 at episode 1883
# Ep 1890 | R= -2195.9 | Best= -1509.4 | Loss=4.1046 | ent=0.6518 | ent_coeff=0.0020 | shortfall=359
# Ep 1900 | R= -2273.0 | Best= -1509.4 | Loss=4.1666 | ent=0.6301 | ent_coeff=0.0020 | shortfall=343
# Ep 1910 | R= -1885.2 | Best= -1509.4 | Loss=3.5874 | ent=0.5953 | ent_coeff=0.0020 | shortfall=338
# Ep 1920 | R= -2212.5 | Best= -1509.4 | Loss=4.0633 | ent=0.6038 | ent_coeff=0.0020 | shortfall=340
# Ep 1930 | R= -1854.8 | Best= -1509.4 | Loss=3.8433 | ent=0.6040 | ent_coeff=0.0020 | shortfall=328
# Ep 1940 | R= -1648.5 | Best= -1509.4 | Loss=3.8926 | ent=0.6159 | ent_coeff=0.0020 | shortfall=319
# Ep 1950 | R= -2386.1 | Best= -1509.4 | Loss=4.3961 | ent=0.6455 | ent_coeff=0.0020 | shortfall=358
# Ep 1960 | R= -2178.1 | Best= -1509.4 | Loss=4.5593 | ent=0.6432 | ent_coeff=0.0020 | shortfall=357
#   NEW BEST: -1433.4 at episode 1970
# Ep 1970 | R= -1433.4 | Best= -1433.4 | Loss=3.3382 | ent=0.6025 | ent_coeff=0.0020 | shortfall=287
# Ep 1980 | R= -1795.6 | Best= -1433.4 | Loss=3.4812 | ent=0.5511 | ent_coeff=0.0020 | shortfall=331
# Ep 1990 | R= -1493.8 | Best= -1433.4 | Loss=2.9239 | ent=0.5079 | ent_coeff=0.0020 | shortfall=320
# Ep 2000 | R= -1811.6 | Best= -1433.4 | Loss=3.4280 | ent=0.5663 | ent_coeff=0.0020 | shortfall=307
#   NEW BEST: -1336.5 at episode 2006
# Ep 2010 | R= -1717.7 | Best= -1336.5 | Loss=3.5570 | ent=0.5951 | ent_coeff=0.0020 | shortfall=303
#   NEW BEST: -1267.6 at episode 2012
# Ep 2020 | R= -1874.6 | Best= -1267.6 | Loss=3.9687 | ent=0.6136 | ent_coeff=0.0020 | shortfall=302
# Ep 2030 | R= -1654.3 | Best= -1267.6 | Loss=3.2818 | ent=0.5652 | ent_coeff=0.0020 | shortfall=334
# Ep 2040 | R= -1636.6 | Best= -1267.6 | Loss=3.5012 | ent=0.5643 | ent_coeff=0.0020 | shortfall=309
# Ep 2050 | R= -1412.2 | Best= -1267.6 | Loss=3.0324 | ent=0.5224 | ent_coeff=0.0020 | shortfall=294
# Ep 2060 | R= -1368.6 | Best= -1267.6 | Loss=2.9500 | ent=0.5121 | ent_coeff=0.0020 | shortfall=298
# Ep 2070 | R= -1595.2 | Best= -1267.6 | Loss=2.9646 | ent=0.5098 | ent_coeff=0.0020 | shortfall=310
# Ep 2080 | R= -1318.1 | Best= -1267.6 | Loss=2.9741 | ent=0.5295 | ent_coeff=0.0020 | shortfall=290
# Ep 2090 | R= -1512.1 | Best= -1267.6 | Loss=2.9259 | ent=0.5354 | ent_coeff=0.0020 | shortfall=309
# Ep 2100 | R= -2186.8 | Best= -1267.6 | Loss=4.3160 | ent=0.5856 | ent_coeff=0.0020 | shortfall=324
# Ep 2110 | R= -1924.9 | Best= -1267.6 | Loss=3.7273 | ent=0.5485 | ent_coeff=0.0020 | shortfall=329
# Ep 2120 | R= -1330.3 | Best= -1267.6 | Loss=2.8634 | ent=0.5415 | ent_coeff=0.0020 | shortfall=300
# Ep 2130 | R= -2149.0 | Best= -1267.6 | Loss=4.4050 | ent=0.5818 | ent_coeff=0.0020 | shortfall=327
# Ep 2140 | R= -2033.9 | Best= -1267.6 | Loss=4.1541 | ent=0.5852 | ent_coeff=0.0020 | shortfall=327
# Ep 2150 | R= -1473.2 | Best= -1267.6 | Loss=2.9144 | ent=0.4890 | ent_coeff=0.0020 | shortfall=321
#   NEW BEST: -1195.8 at episode 2151
#   NEW BEST: -988.9 at episode 2155
# Ep 2160 | R= -1659.8 | Best=  -988.9 | Loss=3.4189 | ent=0.4943 | ent_coeff=0.0020 | shortfall=352
# Ep 2170 | R= -1197.2 | Best=  -988.9 | Loss=2.8845 | ent=0.5404 | ent_coeff=0.0020 | shortfall=295
# Ep 2180 | R= -1816.4 | Best=  -988.9 | Loss=3.1351 | ent=0.4893 | ent_coeff=0.0020 | shortfall=340
# Ep 2190 | R= -1357.1 | Best=  -988.9 | Loss=3.0478 | ent=0.4920 | ent_coeff=0.0020 | shortfall=311
# Ep 2200 | R= -1167.6 | Best=  -988.9 | Loss=2.8448 | ent=0.5710 | ent_coeff=0.0020 | shortfall=287
#   NEW BEST: -921.3 at episode 2204
# Ep 2210 | R= -1760.6 | Best=  -921.3 | Loss=4.2179 | ent=0.5819 | ent_coeff=0.0020 | shortfall=312
# Ep 2220 | R= -1468.6 | Best=  -921.3 | Loss=3.2909 | ent=0.5422 | ent_coeff=0.0020 | shortfall=311
# Ep 2230 | R= -1694.1 | Best=  -921.3 | Loss=3.5273 | ent=0.5544 | ent_coeff=0.0020 | shortfall=321
# Ep 2240 | R= -1582.3 | Best=  -921.3 | Loss=3.2307 | ent=0.5342 | ent_coeff=0.0020 | shortfall=316
# Ep 2250 | R= -1286.4 | Best=  -921.3 | Loss=3.0057 | ent=0.5152 | ent_coeff=0.0020 | shortfall=298
# Ep 2260 | R= -1066.7 | Best=  -921.3 | Loss=2.3824 | ent=0.5137 | ent_coeff=0.0020 | shortfall=288
# Ep 2270 | R= -1288.8 | Best=  -921.3 | Loss=2.6188 | ent=0.5064 | ent_coeff=0.0020 | shortfall=306
# Ep 2280 | R= -1581.5 | Best=  -921.3 | Loss=3.1142 | ent=0.5347 | ent_coeff=0.0020 | shortfall=327
# Ep 2290 | R= -1120.6 | Best=  -921.3 | Loss=2.4815 | ent=0.5141 | ent_coeff=0.0020 | shortfall=297
# Ep 2300 | R= -1352.1 | Best=  -921.3 | Loss=2.8907 | ent=0.4867 | ent_coeff=0.0020 | shortfall=311
#   NEW BEST: -854.7 at episode 2310
# Ep 2310 | R=  -854.7 | Best=  -854.7 | Loss=2.4950 | ent=0.5072 | ent_coeff=0.0020 | shortfall=269
#   NEW BEST: -792.1 at episode 2315
# Ep 2320 | R= -1288.7 | Best=  -792.1 | Loss=2.8208 | ent=0.4484 | ent_coeff=0.0020 | shortfall=329
#   NEW BEST: -751.3 at episode 2329
# Ep 2330 | R= -1183.1 | Best=  -751.3 | Loss=2.4317 | ent=0.4749 | ent_coeff=0.0020 | shortfall=289
#   NEW BEST: -559.3 at episode 2333
# Ep 2340 | R=  -906.8 | Best=  -559.3 | Loss=2.4786 | ent=0.4678 | ent_coeff=0.0020 | shortfall=303
# Ep 2350 | R= -1420.4 | Best=  -559.3 | Loss=3.2180 | ent=0.5274 | ent_coeff=0.0020 | shortfall=285
# Ep 2360 | R= -1101.0 | Best=  -559.3 | Loss=2.5911 | ent=0.4733 | ent_coeff=0.0020 | shortfall=318
# Ep 2370 | R= -1050.5 | Best=  -559.3 | Loss=2.5698 | ent=0.4504 | ent_coeff=0.0020 | shortfall=320
# Ep 2380 | R=  -999.2 | Best=  -559.3 | Loss=2.1541 | ent=0.4452 | ent_coeff=0.0020 | shortfall=289
# Ep 2390 | R= -1726.7 | Best=  -559.3 | Loss=3.4465 | ent=0.4282 | ent_coeff=0.0020 | shortfall=373
# Ep 2400 | R= -1072.0 | Best=  -559.3 | Loss=2.3073 | ent=0.4526 | ent_coeff=0.0020 | shortfall=301
# Ep 2410 | R=  -822.5 | Best=  -559.3 | Loss=2.2488 | ent=0.4568 | ent_coeff=0.0020 | shortfall=268
# Ep 2420 | R= -1062.4 | Best=  -559.3 | Loss=2.2928 | ent=0.4254 | ent_coeff=0.0020 | shortfall=310
#   NEW BEST: -453.2 at episode 2426
# Ep 2430 | R= -1864.1 | Best=  -453.2 | Loss=3.1494 | ent=0.4567 | ent_coeff=0.0020 | shortfall=317
# Ep 2440 | R=  -933.8 | Best=  -453.2 | Loss=1.8885 | ent=0.4358 | ent_coeff=0.0020 | shortfall=292
# Ep 2450 | R= -1264.0 | Best=  -453.2 | Loss=2.7524 | ent=0.4528 | ent_coeff=0.0020 | shortfall=290
# Ep 2460 | R=  -970.5 | Best=  -453.2 | Loss=2.4944 | ent=0.4519 | ent_coeff=0.0020 | shortfall=290
# Ep 2470 | R= -1170.6 | Best=  -453.2 | Loss=2.5972 | ent=0.4168 | ent_coeff=0.0020 | shortfall=316
# Ep 2480 | R= -1221.2 | Best=  -453.2 | Loss=2.8622 | ent=0.4539 | ent_coeff=0.0020 | shortfall=293
# Ep 2490 | R=  -480.6 | Best=  -453.2 | Loss=1.5943 | ent=0.4309 | ent_coeff=0.0020 | shortfall=256
# Ep 2500 | R=  -517.0 | Best=  -453.2 | Loss=1.7970 | ent=0.4228 | ent_coeff=0.0020 | shortfall=266
# Ep 2510 | R=  -793.4 | Best=  -453.2 | Loss=1.9867 | ent=0.4034 | ent_coeff=0.0020 | shortfall=278
# Ep 2520 | R=  -589.8 | Best=  -453.2 | Loss=2.0762 | ent=0.4137 | ent_coeff=0.0020 | shortfall=269
# Ep 2530 | R=  -684.9 | Best=  -453.2 | Loss=2.0910 | ent=0.3902 | ent_coeff=0.0020 | shortfall=293
# Ep 2540 | R=  -528.6 | Best=  -453.2 | Loss=2.0288 | ent=0.4091 | ent_coeff=0.0020 | shortfall=254
#   NEW BEST: -355.4 at episode 2546
# Ep 2550 | R=  -931.6 | Best=  -355.4 | Loss=2.9374 | ent=0.4325 | ent_coeff=0.0020 | shortfall=278
# Ep 2560 | R=  -891.2 | Best=  -355.4 | Loss=2.8903 | ent=0.4339 | ent_coeff=0.0020 | shortfall=261
# Ep 2570 | R=  -613.7 | Best=  -355.4 | Loss=2.3228 | ent=0.4049 | ent_coeff=0.0020 | shortfall=252
# Ep 2580 | R=  -694.7 | Best=  -355.4 | Loss=2.4482 | ent=0.3917 | ent_coeff=0.0020 | shortfall=281
# Ep 2590 | R=  -751.7 | Best=  -355.4 | Loss=2.5816 | ent=0.3811 | ent_coeff=0.0020 | shortfall=277
# Ep 2600 | R=  -788.5 | Best=  -355.4 | Loss=2.8486 | ent=0.3619 | ent_coeff=0.0020 | shortfall=289
# Ep 2610 | R=  -695.1 | Best=  -355.4 | Loss=2.7571 | ent=0.3969 | ent_coeff=0.0020 | shortfall=282
# Ep 2620 | R=  -569.7 | Best=  -355.4 | Loss=3.0135 | ent=0.4102 | ent_coeff=0.0020 | shortfall=249
# Ep 2630 | R=  -707.5 | Best=  -355.4 | Loss=2.8778 | ent=0.3965 | ent_coeff=0.0020 | shortfall=278
#   NEW BEST: -288.9 at episode 2636
# Ep 2640 | R=  -542.6 | Best=  -288.9 | Loss=2.7637 | ent=0.4020 | ent_coeff=0.0020 | shortfall=268
# Ep 2650 | R=  -672.4 | Best=  -288.9 | Loss=3.1677 | ent=0.4145 | ent_coeff=0.0020 | shortfall=267
# Ep 2660 | R=  -958.6 | Best=  -288.9 | Loss=3.2253 | ent=0.3970 | ent_coeff=0.0020 | shortfall=276
# Ep 2670 | R=  -675.9 | Best=  -288.9 | Loss=3.5463 | ent=0.4333 | ent_coeff=0.0020 | shortfall=259
# Ep 2680 | R=  -859.3 | Best=  -288.9 | Loss=3.2854 | ent=0.4041 | ent_coeff=0.0020 | shortfall=285
# Ep 2690 | R=  -794.4 | Best=  -288.9 | Loss=3.6200 | ent=0.4218 | ent_coeff=0.0020 | shortfall=275
# Ep 2700 | R= -1604.5 | Best=  -288.9 | Loss=5.0014 | ent=0.4884 | ent_coeff=0.0020 | shortfall=296
# Ep 2710 | R=  -866.5 | Best=  -288.9 | Loss=3.0495 | ent=0.4102 | ent_coeff=0.0020 | shortfall=290
# Ep 2720 | R=  -974.4 | Best=  -288.9 | Loss=3.4361 | ent=0.4286 | ent_coeff=0.0020 | shortfall=296
# Ep 2730 | R= -1085.6 | Best=  -288.9 | Loss=3.4116 | ent=0.4750 | ent_coeff=0.0020 | shortfall=283
# Ep 2740 | R= -1188.6 | Best=  -288.9 | Loss=3.6722 | ent=0.4472 | ent_coeff=0.0020 | shortfall=319
# Ep 2750 | R= -1138.9 | Best=  -288.9 | Loss=3.2418 | ent=0.4269 | ent_coeff=0.0020 | shortfall=301
# Ep 2760 | R=  -920.1 | Best=  -288.9 | Loss=3.7491 | ent=0.4585 | ent_coeff=0.0020 | shortfall=278
# Ep 2770 | R= -1809.9 | Best=  -288.9 | Loss=4.9558 | ent=0.5029 | ent_coeff=0.0020 | shortfall=320
# Ep 2780 | R= -2106.4 | Best=  -288.9 | Loss=5.2859 | ent=0.4768 | ent_coeff=0.0020 | shortfall=332
# Ep 2790 | R= -1767.7 | Best=  -288.9 | Loss=4.5516 | ent=0.4613 | ent_coeff=0.0020 | shortfall=317
# Ep 2800 | R= -1074.7 | Best=  -288.9 | Loss=3.7267 | ent=0.4680 | ent_coeff=0.0020 | shortfall=277
# Ep 2810 | R= -1400.7 | Best=  -288.9 | Loss=3.9832 | ent=0.4550 | ent_coeff=0.0020 | shortfall=306
# Ep 2820 | R= -2217.9 | Best=  -288.9 | Loss=5.3914 | ent=0.5047 | ent_coeff=0.0020 | shortfall=319
# Ep 2830 | R= -2045.7 | Best=  -288.9 | Loss=5.4098 | ent=0.5077 | ent_coeff=0.0020 | shortfall=323
# Ep 2840 | R= -2907.1 | Best=  -288.9 | Loss=5.8009 | ent=0.4976 | ent_coeff=0.0020 | shortfall=356
# Ep 2850 | R= -1495.0 | Best=  -288.9 | Loss=4.1542 | ent=0.5064 | ent_coeff=0.0020 | shortfall=297
# Ep 2860 | R= -1524.6 | Best=  -288.9 | Loss=3.9714 | ent=0.4909 | ent_coeff=0.0020 | shortfall=292
# Ep 2870 | R= -1399.6 | Best=  -288.9 | Loss=3.4804 | ent=0.4688 | ent_coeff=0.0020 | shortfall=299
# Ep 2880 | R= -1787.4 | Best=  -288.9 | Loss=3.4166 | ent=0.4409 | ent_coeff=0.0020 | shortfall=321
# Ep 2890 | R= -1389.0 | Best=  -288.9 | Loss=3.2606 | ent=0.4666 | ent_coeff=0.0020 | shortfall=297
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 42
#      38 batch = traj.to_tensors()
#      40 advantages, returns = compute_gae(traj.rewards, traj.values, GAMMA, LAM)
# ---> 42 mean_loss, mean_entropy = ppo_update(
#      43     model, optimizer, batch, advantages, returns,
#      44     clip_eps=CLIP_EPS,
#      45     value_coeff=VALUE_COEFF,
#      46     entropy_coeff=entropy_coeff,
#      47     K_epochs=K_EPOCHS,
#      48     mini_batch_size=MINI_BATCH_SIZE,
#      49 )
#      51 total_reward = sum(traj.rewards)
#      53 if total_reward > best_reward:
#
# Cell In[40], line 23, in ppo_update(model, optimizer, batch, advantages, returns, clip_eps, value_coeff, entropy_coeff, K_epochs, mini_batch_size)
#      14 probs_new, values_new = model(
#      15     batch["emp_ids"][idx],
#      16     batch["day_ids"][idx],
#    (...)     19     batch["action_masks"][idx],
#      20 )
#      22 dist_now      = Categorical(probs=probs_new)
# ---> 23 a_logprob_now = dist_now.log_prob(batch["actions"][idx])
#      24 dist_entropy  = dist_now.entropy()
#      26 ratios = torch.exp(a_logprob_now - batch["log_probs_old"][idx])
#
# File ~/.local/lib/python3.11/site-packages/torch/distributions/categorical.py:137, in Categorical.log_prob(self, value)
#     135 def log_prob(self, value):
#     136     if self._validate_args:
# --> 137         self._validate_sample(value)
#     138     value = value.long().unsqueeze(-1)
#     139     value, log_pmf = torch.broadcast_tensors(value, self.logits)
#
# File ~/.local/lib/python3.11/site-packages/torch/distributions/distribution.py:311, in Distribution._validate_sample(self, value)
#     309 assert support is not None
#     310 valid = support.check(value)
# --> 311 if not valid.all():
#     312     raise ValueError(
#     313         "Expected value argument "
#     314         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)    317         f"but found invalid values:\n{value}"
#     318     )
#
# KeyboardInterrupt:

# %%
def evaluate(model, env, greedy=False):
    model.eval()                                                                                                                                                                                                                           
    env.reset()
    terminated = truncated = False                                                                                                                                                                                                         
    total_reward = 0.0

    with torch.no_grad():
        while not (terminated or truncated):
            emp_id = int(env.state[env.current_step, 0])
            day_id = int(env.state[env.current_step, 1])                                                                                                                                                                                   

            cov_gap = [                                                                                                                                                                                                                    
                env.min_demand[day_id, 0, 0] - env.daily_coverage[day_id, 0, 0],
                env.min_demand[day_id, 1, 0] - env.daily_coverage[day_id, 1, 0],                                                                                                                                                           
                env.min_demand[day_id, 0, 1] - env.daily_coverage[day_id, 0, 1],
                env.min_demand[day_id, 1, 1] - env.daily_coverage[day_id, 1, 1],                                                                                                                                                           
            ]   
            remaining_budget = env.max_days_per_year - env.days_worked[emp_id]                                                                                                                                                             
            remaining_cal = max(1, env.num_days - day_id)                                                                                                                                                                               
            pace_ratio = remaining_budget / remaining_cal
            dyn_feat = [env.days_worked[emp_id], env.consecutive_days[emp_id], pace_ratio]                                                                                                                                                 
            action_mask = env.get_action_mask()                                                                                                                                                                                            

            emp_id_t = torch.tensor([emp_id], dtype=torch.long)                                                                                                                                                                           
            day_id_t = torch.tensor([day_id], dtype=torch.long)
            cov_gap_t = torch.tensor([cov_gap], dtype=torch.float32)                                                                                                                                                                       
            dyn_feat_t = torch.tensor([dyn_feat], dtype=torch.float32)
            mask_t = torch.tensor([action_mask], dtype=torch.bool)                                                                                                                                                                      
                
            probs, _ = model(emp_id_t, day_id_t, cov_gap_t, dyn_feat_t, mask_t)                                                                                                                                                            
            action = probs[0].argmax() if greedy else Categorical(probs=probs[0]).sample()
            _, reward, terminated, truncated, _ = env.step(action.item())                                                                                                                                                                  
            total_reward += reward

    shortfall = int(np.maximum(0, env.min_demand - env.daily_coverage).sum())                                                                                                                                                              

    # Extract schedule                                                                                                                                                                                                                     
    labels = {0: "-", 1: "M-A", 2: "T-A", 3: "M-B", 4: "T-B"}
    schedule = []                                                                                                                                                                                                                          
    for emp in range(env.num_employees):
        row = []                                                                                                                                                                                                                           
        for day in range(env.num_days):
            r = env.state[env._row(emp, day), 2:]                                                                                                                                                                                          
            row.append(labels[int(np.argmax(r))] if r.sum() > 0 else "-")                                                                                                                                                                  
        schedule.append(row)                                                                                                                                                                                                               
                                                                                                                                                                                                                                            
    return total_reward, shortfall, env.days_worked.tolist(), schedule, env                                                                                                                                                                
                
                                                                                                                                                                                                                                            
# Load checkpoint
ckpt = torch.load("best_of_all.pth", weights_only=True)
model.load_state_dict(ckpt["model_state_dict"])                                                                                                                                                                                            
print(f"Checkpoint: episode {ckpt['episode']}, best reward = {ckpt['best_reward']:.1f}\n")
                                                                                                                                                                                                                                            
# Generate 20 schedules                                                                                                                                                                                                                    
N = 20
results = []                                                                                                                                                                                                                               
for i in range(N):
    reward, shortfall, days_worked, schedule, env_snap = evaluate(model, env, greedy=False)
    results.append((reward, shortfall, days_worked, schedule, env_snap))                                                                                                                                                                   
    print(f"Run {i+1:2d} | Reward: {reward:8.1f} | Shortfall: {shortfall:3d} | Days worked: {days_worked}")
                                                                                                                                                                                                                                            
# Find best     
best_idx = min(range(N), key=lambda i: results[i][1])  # lowest shortfall                                                                                                                                                                  
best_reward, best_shortfall, best_days, best_schedule, best_env = results[best_idx]                                                                                                                                                        

print(f"\n{'='*60}")                                                                                                                                                                                                                       
print(f"BEST: Run {best_idx+1} | Reward: {best_reward:.1f} | Shortfall: {best_shortfall}")
print(f"Days worked/employee: {best_days}")                                                                                                                                                                                                
print(f"{'='*60}\n")
                                                                                                                                                                                                                                            
shift_names = {(0,0): "M-A", (1,0): "T-A", (0,1): "M-B", (1,1): "T-B"}
for d in range(best_env.num_days):                                                                                                                                                                                                         
    gaps = []   
    for s in range(2):                                                                                                                                                                                                                     
        for t in range(2):
            gap = int(best_env.min_demand[d, s, t] - best_env.daily_coverage[d, s, t])
            if gap > 0:                                                                                                                                                                                                                    
                gaps.append(f"{shift_names[(s,t)]}={gap}")
    if gaps:                                                                                                                                                                                                                               
        print(f"Day {d:3d}: {', '.join(gaps)}")
                                                                                                                                                                                                                                            
# Print schedules
print()                                                                                                                                                                                                                                    
for emp in range(len(best_schedule)):
    print(f"Employee {emp+1:2d}: {best_schedule[emp]}")                                                                                                                                                                                    

# Write best schedule to CSV                                                                                                                                                                                                               
import csv      
with open("best_schedule.csv", "w", newline="") as f:
    writer = csv.writer(f)                                                                                                                                                                                                                 
    header = ["Employee"] + [f"Day_{d}" for d in range(len(best_schedule[0]))]
    writer.writerow(header)                                                                                                                                                                                                                
    for emp in range(len(best_schedule)):
        writer.writerow([f"Employee_{emp+1}"] + best_schedule[emp])                                                                                                                                                                        
                                                                                                                                                                                                                                            
print(f"\nBest schedule written to best_schedule.csv")
# Out:
# Checkpoint: episode 2636, best reward = -288.9
# /tmp/ipykernel_5926/3226569752.py:28: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   mask_t = torch.tensor([action_mask], dtype=torch.bool)
# Run  1 | Reward:   -918.5 | Shortfall: 272 | Days worked: [223, 223, 223, 220, 209, 223, 215, 223, 222, 223, 216, 223]
# Run  2 | Reward:  -1533.6 | Shortfall: 293 | Days worked: [223, 223, 223, 216, 204, 214, 201, 223, 223, 223, 220, 223]
# Run  3 | Reward:  -1163.9 | Shortfall: 267 | Days worked: [223, 223, 223, 212, 215, 221, 212, 223, 223, 223, 208, 223]
# Run  4 | Reward:  -1235.1 | Shortfall: 278 | Days worked: [223, 223, 223, 223, 205, 214, 206, 223, 223, 223, 221, 223]
# Run  5 | Reward:   -856.1 | Shortfall: 253 | Days worked: [223, 223, 223, 223, 208, 203, 212, 223, 223, 223, 221, 223]
# Run  6 | Reward:   -958.4 | Shortfall: 273 | Days worked: [223, 223, 223, 223, 200, 210, 219, 223, 223, 223, 219, 223]
# Run  7 | Reward:  -1199.1 | Shortfall: 293 | Days worked: [223, 223, 223, 223, 201, 220, 221, 217, 223, 223, 211, 223]
# Run  8 | Reward:   -651.7 | Shortfall: 251 | Days worked: [223, 223, 223, 223, 210, 212, 217, 223, 223, 223, 222, 223]
# Run  9 | Reward:  -1338.6 | Shortfall: 290 | Days worked: [223, 223, 223, 223, 206, 214, 212, 217, 223, 223, 223, 223]
# Run 10 | Reward:   -816.0 | Shortfall: 247 | Days worked: [223, 223, 223, 223, 197, 219, 210, 223, 223, 223, 223, 223]
# Run 11 | Reward:   -941.4 | Shortfall: 276 | Days worked: [223, 223, 223, 223, 199, 223, 223, 223, 223, 223, 210, 223]
# Run 12 | Reward:   -592.1 | Shortfall: 260 | Days worked: [223, 223, 223, 219, 209, 223, 217, 223, 222, 223, 215, 223]
# Run 13 | Reward:   -702.7 | Shortfall: 261 | Days worked: [223, 223, 223, 219, 218, 223, 213, 223, 218, 223, 223, 223]
# Run 14 | Reward:  -1061.6 | Shortfall: 298 | Days worked: [223, 223, 223, 223, 222, 217, 221, 223, 212, 223, 219, 223]
# Run 15 | Reward:   -931.7 | Shortfall: 284 | Days worked: [223, 223, 223, 223, 217, 223, 211, 223, 223, 223, 223, 223]
# Run 16 | Reward:  -1275.2 | Shortfall: 292 | Days worked: [223, 223, 223, 214, 206, 218, 217, 223, 223, 223, 215, 223]
# Run 17 | Reward:  -1222.6 | Shortfall: 273 | Days worked: [223, 223, 223, 220, 202, 213, 205, 223, 218, 223, 223, 223]
# Run 18 | Reward:   -939.4 | Shortfall: 281 | Days worked: [223, 223, 223, 223, 214, 223, 209, 223, 223, 223, 206, 223]
# Run 19 | Reward:  -1035.2 | Shortfall: 291 | Days worked: [223, 223, 223, 212, 210, 223, 220, 223, 223, 223, 218, 223]
# Run 20 | Reward:  -1160.6 | Shortfall: 266 | Days worked: [223, 223, 223, 223, 206, 215, 205, 212, 223, 223, 222, 223]
#
# ============================================================
# BEST: Run 10 | Reward: -816.0 | Shortfall: 247
# Days worked/employee: [223, 223, 223, 223, 197, 219, 210, 223, 223, 223, 223, 223]
# ============================================================
#
# Day   5: M-A=1
# Day   6: T-A=1
# Day  15: M-B=1
# Day  17: T-A=1, T-B=1
# Day  19: M-B=1
# Day  23: T-B=1
# Day  26: M-A=1
# Day  27: M-A=1, M-B=1
# Day  28: M-B=1
# Day  29: T-B=1
# Day  33: M-A=1, M-B=1
# Day  34: M-B=1
# Day  35: T-A=1
# Day  36: T-A=1
# Day  37: T-A=2
# Day  40: T-A=1, T-B=1
# Day  42: M-B=1
# Day  43: T-A=1, T-B=1
# Day  44: T-A=2
# Day  46: M-B=1
# Day  47: M-B=1
# Day  48: M-B=1
# Day  53: T-B=1
# Day  54: T-A=1, T-B=1
# Day  56: T-A=2
# Day  59: M-A=1
# Day  60: T-B=1
# Day  61: T-A=1, T-B=1
# Day  65: M-B=1, T-B=1
# Day  67: T-B=1
# Day  74: T-B=1
# Day  75: T-A=1
# Day  78: T-A=1
# Day  80: T-A=1, T-B=1
# Day  89: T-A=1
# Day  92: T-B=1
# Day  94: M-B=1
# Day  95: M-B=1
# Day  97: M-B=1
# Day 100: M-B=1
# Day 101: T-A=1
# Day 104: T-B=1
# Day 106: M-B=1
# Day 109: T-A=1
# Day 110: T-A=1, T-B=1
# Day 112: M-B=1, T-A=1
# Day 113: T-A=2
# Day 114: T-A=2
# Day 116: T-B=1
# Day 119: T-A=2
# Day 122: T-B=1
# Day 124: M-B=1
# Day 128: M-B=1, T-B=1
# Day 130: T-A=1
# Day 134: T-B=1
# Day 138: M-A=1
# Day 140: T-B=1
# Day 142: M-B=1
# Day 144: M-B=1
# Day 146: T-B=1
# Day 152: T-B=1
# Day 153: T-A=1
# Day 158: T-B=1
# Day 168: M-A=1
# Day 169: M-B=1
# Day 170: T-B=1
# Day 171: T-A=1
# Day 176: M-B=1
# Day 177: T-A=1
# Day 179: M-B=1, T-B=1
# Day 183: T-A=1
# Day 184: M-B=1, T-A=1
# Day 185: T-B=1
# Day 186: T-B=1
# Day 192: M-A=2
# Day 193: M-B=1, T-B=1
# Day 199: T-A=2, T-B=1
# Day 200: T-B=1
# Day 203: M-B=1
# Day 206: T-A=1
# Day 207: T-B=1
# Day 213: M-A=1
# Day 214: T-B=1
# Day 219: M-B=1
# Day 220: M-A=1, T-B=1
# Day 221: M-B=1, T-B=1
# Day 226: T-B=1
# Day 228: T-B=1
# Day 235: T-B=1
# Day 241: M-A=2, M-B=1
# Day 242: M-A=1, M-B=1, T-B=1
# Day 248: M-A=1, M-B=1
# Day 249: M-B=1, T-B=1
# Day 255: M-B=1, T-A=1, T-B=1
# Day 256: M-B=1, T-B=1
# Day 262: T-B=1
# Day 263: M-B=1, T-A=1, T-B=1
# Day 269: M-A=1
# Day 270: M-B=1, T-B=1
# Day 276: M-A=2, M-B=1
# Day 277: M-A=1, M-B=1, T-B=1
# Day 283: T-A=2, T-B=1
# Day 284: M-B=1, T-B=1
# Day 290: M-A=2, M-B=1
# Day 291: M-A=1, M-B=1, T-B=1
# Day 297: M-A=2, M-B=1
# Day 298: M-A=1, M-B=1, T-A=1, T-B=1
# Day 304: M-A=1, M-B=1, T-A=2, T-B=1
# Day 305: M-A=1, M-B=1, T-A=1, T-B=1
# Day 309: M-B=1
# Day 310: M-B=1
# Day 311: M-A=2, M-B=1
# Day 312: M-A=1, M-B=1, T-A=1, T-B=1
# Day 315: M-B=1
# Day 316: M-B=1
# Day 317: M-B=1
# Day 318: T-B=1
# Day 319: M-A=1, M-B=1, T-A=1, T-B=1
# Day 322: T-A=1, T-B=1
# Day 325: M-A=1, M-B=1
# Day 326: M-A=1, M-B=1, T-A=1, T-B=1
# Day 327: T-A=1, T-B=1
# Day 332: M-A=1, M-B=1, T-A=1, T-B=1
# Day 333: M-A=1, M-B=1, T-A=1, T-B=1
# Day 334: M-A=2, M-B=1, T-A=2, T-B=1
# Day 336: M-B=1
# Day 337: M-A=1, M-B=1
# Day 338: M-A=1, M-B=1
# Day 339: M-A=1
# Day 340: M-A=1, M-B=1, T-A=1, T-B=1
# Day 341: M-A=2, M-B=1, T-A=2, T-B=1
# Day 344: T-B=1
# Day 346: T-B=1
# Day 347: M-A=1, M-B=1, T-A=1, T-B=1
# Day 348: T-B=1
# Day 351: M-A=1
# Day 352: M-A=1
# Day 353: M-A=2, M-B=1, T-A=1, T-B=1
# Day 354: M-A=1, M-B=1, T-A=1, T-B=1
# Day 355: M-A=1
# Day 356: M-A=1
# Day 357: M-A=1, M-B=1
# Day 358: M-A=2, M-B=1, T-A=2, T-B=1
# Day 359: M-A=1
# Day 360: M-A=1
# Day 361: M-A=1, M-B=1, T-A=1, T-B=1
# Day 362: M-A=1
# Day 363: M-A=1, T-B=1
# Day 364: M-A=1, T-B=1
#
# Employee  1: ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-']
# Employee  2: ['M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-']
# Employee  3: ['M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'T-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'T-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'T-A', 'T-A', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'M-A', 'M-A', 'T-A', 'T-A', 'T-A', '-', '-', 'M-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', '-', 'M-A', 'M-A', '-', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', '-', 'M-A', 'M-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', '-', 'T-A', '-', 'M-A', '-', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-']
# Employee  4: ['-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', '-', 'M-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'M-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', '-', '-', 'M-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', '-', 'M-A', 'T-A', '-', '-', '-', '-', 'M-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', '-', 'M-A', 'M-A', 'T-A', '-', 'T-A', '-', 'M-A', 'M-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'M-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'M-A', 'T-A', 'T-A', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'M-A', 'M-A', '-', 'T-A', 'T-A', '-', 'M-A', 'M-A', 'T-A', 'T-A', 'T-A', '-', '-', 'M-A', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', '-', '-', '-', '-', 'M-A', 'M-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'M-A', 'T-A', '-', 'T-A', 'T-A', '-', 'M-A', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', '-', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'M-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'M-A', '-', 'M-A', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', '-', '-', 'M-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'T-A', '-', '-', 'M-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'M-A', 'M-A', 'M-A', '-', 'M-A', '-', '-', '-', '-', '-']
# Employee  5: ['T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'M-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'M-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', '-', 'M-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', '-', '-', '-', '-', 'T-A', '-', '-', '-', '-', 'T-A', '-', 'T-A', '-', 'T-A', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'M-A', 'T-A', 'T-A', '-', '-', '-', 'M-A', 'M-A', '-', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', '-', 'T-A', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'M-A', 'T-A', '-', 'T-A', '-', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', '-', '-', 'T-A', 'T-A', '-', '-', '-', 'M-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'M-A', 'T-A', '-', '-', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', '-', 'T-A', '-', '-', 'T-A', '-', 'M-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', 'T-A', '-', 'M-A', '-', '-', 'T-A', '-', '-', '-', 'M-A', '-', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', '-', '-', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', '-', 'T-A', '-', '-', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', '-', '-', '-', 'T-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'M-A', '-', 'T-A', '-', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A']
# Employee  6: ['T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', '-', 'M-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', '-', '-', '-', '-', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'M-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', '-', '-', '-', 'T-A', 'T-A', '-', 'M-A', 'T-A', '-', '-', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'M-A', 'M-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'M-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', '-', 'T-A', '-', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'M-A', 'M-A', 'M-A', 'M-A', 'M-A', '-', '-', 'T-A', 'T-A', 'T-A', '-', '-', 'M-A', '-', 'T-A', 'T-A', 'T-A']
# Employee  7: ['-', '-', 'M-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', '-', '-', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'T-A', '-', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'T-A', 'T-A', '-', '-', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'T-A', 'T-A', '-', 'T-A', '-', '-', '-', '-', 'T-A', '-', '-', 'T-A', '-', 'M-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', '-', '-', 'T-A', '-', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', '-', '-', '-', 'T-A', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', 'M-A', 'M-A', 'T-A', '-', '-', '-', 'M-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'M-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', '-', 'M-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', 'M-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', '-', '-', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-A', '-', 'M-A', 'T-A', 'T-A', '-', 'T-A', '-', '-', '-', '-', '-', '-', 'M-A', 'M-A', '-', 'T-A', 'T-A', 'T-A', '-', 'M-A', '-', '-', '-', 'T-A', 'T-A', 'T-A', '-', 'M-A', '-', '-', 'M-A', 'M-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', '-', '-', 'M-A', 'M-A', '-', 'T-A', '-', '-', 'T-A', 'T-A', 'T-A']
# Employee  8: ['M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', 'M-B', 'T-B', 'T-A', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'T-B', '-', 'T-B', '-', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'T-B', 'T-A', '-', '-', 'T-A', 'T-A', '-', '-', '-', 'M-B', 'M-B', 'T-A', '-', 'M-B', 'T-A', '-', 'M-B', '-', 'M-A', 'T-A', '-', 'M-B', 'T-A', 'T-B', '-', 'M-B', '-', 'M-B', 'T-B', 'T-A', 'T-A', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'T-B', '-', '-', 'M-B', 'M-B', 'T-A', 'T-A', '-', 'M-B', '-', 'M-B', '-', 'M-B', '-', '-', '-', '-', 'M-B', '-', 'M-B', '-', '-', 'M-B', '-', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'T-A', '-', 'M-B', '-', 'M-B', 'T-A', 'T-A', '-', 'M-B', 'T-A', '-', 'M-B', 'M-B', 'T-A', 'T-A', '-', 'M-B', '-', '-', 'M-B', 'M-B', 'T-A', 'T-A', '-', '-', 'T-A', '-', 'M-B', 'M-B', 'M-B', 'T-A', '-', '-', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', 'T-A', '-', 'M-B', 'T-A', 'T-A', '-', '-', 'M-B', 'M-B', '-', 'T-B', '-', 'M-B', 'M-B', '-', '-', 'T-A', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'M-B', 'M-B', 'M-B', 'T-A', '-', 'M-B', 'T-A', '-', 'M-B', 'T-A', '-', 'M-B', 'T-B', 'T-A', 'T-A', 'T-A', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', 'T-A', '-', 'M-B', 'T-A', 'T-A', '-', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'T-A', 'T-B', 'T-B', '-', '-', 'M-B', 'M-B', 'M-B', 'T-B', 'T-B', '-', 'M-B', 'M-B', 'M-B', '-', 'T-B', 'T-B', '-', 'M-B', '-', 'M-B', 'M-B', '-', 'M-B', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'T-B', '-', '-', 'M-B', 'T-A', 'T-A', 'T-B', '-', 'M-B', 'M-B', 'T-B', 'T-B', 'T-A', '-', '-', '-', '-', 'T-B', 'T-A', '-', 'M-B', '-', '-', 'T-B', 'T-A', 'T-A', 'T-A', 'T-B', '-', 'M-B', 'T-B', '-', 'M-B', '-', 'M-A', '-', 'M-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'M-B', 'T-A', 'T-B', 'T-B', 'T-B', '-', '-', 'M-B', 'T-A', 'T-A', 'T-B', 'T-B', '-', '-', 'M-B', 'M-B', 'M-B', 'T-B', 'T-A', '-', '-', 'M-B', 'M-B', 'T-A', 'T-B', 'T-B', '-', '-', 'M-B', 'M-B', 'T-B', 'T-A', 'T-B', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', '-', 'M-B', 'T-A', 'T-A', 'T-A', 'T-B', '-', '-', 'M-B', 'M-B', 'M-B', 'T-B', 'T-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'T-A', '-', '-', 'T-B', '-', 'M-B', '-', 'M-A', 'T-B', '-', 'M-A', 'M-A', 'M-A']
# Employee  9: ['M-B', 'M-B', 'M-B', 'T-B', 'T-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'T-A', 'T-A', 'T-A', '-', '-', 'M-B', 'M-B', 'M-B', 'T-A', '-', 'M-B', 'M-B', '-', 'T-A', '-', 'T-B', 'T-A', 'T-B', 'T-A', 'T-B', '-', 'M-B', 'T-A', '-', 'T-A', 'T-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'T-B', '-', 'M-B', 'M-B', '-', '-', '-', '-', 'T-A', '-', 'M-B', '-', '-', 'T-A', 'T-B', '-', 'T-A', '-', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', 'T-A', 'T-A', 'T-B', 'T-A', '-', 'M-B', 'T-A', 'T-A', '-', 'M-B', '-', '-', 'M-B', 'M-B', '-', '-', 'M-B', '-', 'T-A', 'T-B', '-', '-', 'M-B', '-', '-', '-', '-', 'M-B', '-', 'T-A', '-', 'M-B', 'T-A', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', '-', 'T-A', 'T-B', '-', 'M-B', 'T-A', '-', 'M-B', 'T-A', '-', 'T-A', 'T-A', '-', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', '-', 'M-B', 'T-A', '-', '-', '-', 'M-B', 'T-A', '-', 'M-B', 'M-B', '-', 'T-A', '-', 'M-B', 'T-A', '-', 'M-B', 'M-B', 'M-B', 'T-B', 'T-A', '-', 'T-A', 'T-A', 'T-A', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'T-B', 'T-A', '-', 'T-B', 'T-A', 'T-A', 'T-A', 'T-A', '-', 'T-A', 'T-B', 'T-A', 'T-A', 'T-A', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'T-A', '-', '-', 'M-B', 'M-B', 'M-B', 'T-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'T-A', 'T-A', '-', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'T-B', 'T-A', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'T-A', 'T-A', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', '-', 'M-B', 'T-B', 'T-B', '-', 'T-A', 'T-A', '-', 'T-A', '-', 'T-B', '-', 'T-A', 'T-B', '-', 'M-B', 'M-B', '-', '-', 'M-B', 'T-B', '-', 'M-B', 'M-B', 'M-A', '-', 'M-B', '-', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'T-A', 'T-B', '-', '-', 'T-A', '-', 'T-A', 'T-A', 'T-A', 'T-B', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', 'M-B', 'T-B', 'T-B', 'T-A', '-', 'M-B', 'M-B', 'T-A', 'T-B', 'T-B', '-', '-', 'M-B', 'M-B', '-', '-', '-', '-', '-', '-', '-', '-']
# Employee 10: ['M-A', 'T-B', 'T-A', '-', 'M-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'M-B', 'M-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-A', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-A', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-A', '-', 'T-B', 'T-B', '-', 'M-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-A', '-', 'M-B', '-', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-A', 'T-B', 'T-B', '-', 'T-B', 'T-A', 'T-B', '-', 'T-B', '-', 'T-B', 'T-B', '-', 'T-B', '-', 'T-A', '-', 'T-A', '-', 'T-B', 'T-B', '-', 'T-B', 'T-A', 'T-B', 'T-B', 'T-B', '-', '-', '-', 'M-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', '-', '-', 'T-B', 'T-B', 'T-A', 'T-B', 'T-B', '-', 'M-B', 'M-B', 'T-A', '-', 'T-B', 'T-B', 'T-B', '-', '-', '-', '-', 'T-B', '-', 'T-B', '-', 'T-A', '-', 'M-B', 'T-B', 'T-A', 'T-B', '-', 'M-B', 'T-A', 'T-A', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', 'T-B', '-', 'T-A', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-A', 'T-B', 'T-A', 'T-B', 'T-A', '-', 'T-A', 'T-B', 'T-A', 'T-B', 'T-A', '-', 'T-B', 'T-B', 'T-A', 'T-B', 'T-B', '-', 'T-A', 'T-A', 'T-B', 'T-B', 'T-B', '-', 'T-A', 'T-B', '-', '-', 'M-B', 'M-B', 'T-A', 'T-B', '-', '-', 'T-A', 'T-B', 'T-B', 'T-B', '-', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-A', '-', 'M-B', 'M-B', 'T-A', 'T-B', 'T-B', '-', '-', 'T-A', 'T-A', 'T-A', 'T-B', 'T-B', '-', '-', 'M-B', 'T-A', 'T-A', 'T-B', 'T-B', '-', '-', 'M-B', 'M-B', 'M-B', 'T-B', 'T-B', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', 'T-B', 'T-B', 'T-A', 'T-A', '-', '-', 'M-B', 'M-B', 'T-B', 'T-B', 'T-A', '-', '-', 'M-B', 'M-B', 'M-B', 'T-A', 'T-A', '-', '-', 'M-B', 'M-B', 'T-B', 'T-B', 'T-B', '-', '-', 'M-B', 'T-A', 'T-A', '-', 'M-B', 'M-B', '-', '-', 'M-B', 'M-B', 'T-A', 'T-B', 'T-B', '-', 'M-B', 'M-B', 'T-B', 'T-B', 'T-B', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'T-B', 'T-B', '-', '-', 'M-B', 'T-B', 'T-A', 'T-B', 'T-A', '-', '-', 'M-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', '-', 'T-B', '-', 'T-B', 'T-B', 'T-B', '-', '-', 'M-B', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-']
# Employee 11: ['-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'T-B', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', '-', '-', 'M-B', 'T-B', '-', 'M-B', 'M-B', '-', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', 'T-B', '-', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', '-', 'T-B', '-', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', '-', 'M-B', 'M-B', '-', 'T-B', '-', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', '-', '-', 'M-B', '-', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', '-', 'M-B', '-', 'M-B', 'M-B', '-', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', '-', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', '-', '-', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', 'T-B', 'T-B', '-', 'M-B', 'M-B', '-', '-', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', 'M-B', '-', '-', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', '-', 'M-B', 'M-B', '-', 'M-B', '-', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'T-B', '-', 'M-B', 'T-B', '-', 'M-B', 'M-B', 'T-B', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', '-', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', '-', 'M-B', 'M-B', 'M-B', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'M-B', '-', '-', 'M-B', 'M-B', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'T-B', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', 'M-B', '-', 'M-B', 'M-B', '-', 'M-B', 'T-B', '-']
# Employee 12: ['T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'M-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', '-', 'T-B', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', 'T-B', 'T-B', '-', '-', 'T-B', 'T-B', 'T-B', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-']
#
# Best schedule written to best_schedule.csv

# %%
import matplotlib.pyplot as plt

# Run best episode using the existing evaluate_silent function                                                                                                                                                                             
ckpt = torch.load("best_of_all.pth", weights_only=True)
model.load_state_dict(ckpt["model_state_dict"])                                                                                                                                                                                            
_, _, _, _, best_env = evaluate_silent(model, env, greedy=False)                                                                                                                                                                           
                                                                                                                                                                                                                                            
# Extract coverage arrays: shape (num_days, 2 shifts, 2 teams)                                                                                                                                                                             
days = np.arange(best_env.num_days)                                                                                                                                                                                                        
cov = best_env.daily_coverage  # (365, 2, 2)                                                                                                                                                                                               
demand = best_env.min_demand    # (365, 2, 2)                                                                                                                                                                                              

# Plot coverage vs demand for each shift-team                                                                                                                                                                                              
fig, axes = plt.subplots(2, 2, figsize=(16, 8), sharex=True, sharey=True)
shift_team = {(0,0): "M-A", (1,0): "T-A", (0,1): "M-B", (1,1): "T-B"}                                                                                                                                                                      
                                                                                                                                                                                                                                            
for (s, t), name in shift_team.items():                                                                                                                                                                                                    
    ax = axes[s][t]                                                                                                                                                                                                                        
    ax.plot(days, cov[:, s, t], label='Coverage', alpha=0.7)                                                                                                                                                                               
    ax.plot(days, demand[:, s, t], label='Demand', alpha=0.7, linestyle='--', color='r')                                                                                                                                                   
    ax.fill_between(days, cov[:, s, t], demand[:, s, t],                                                                                                                                                                                   
                    where=cov[:, s, t] < demand[:, s, t],                                                                                                                                                                                  
                    color='red', alpha=0.2, label='Shortfall')                                                                                                                                                                             
    ax.set_title(name)
    ax.set_ylabel('Employees')                                                                                                                                                                                                             
    ax.legend(loc='upper right', fontsize=8)
                                                                                                                                                                                                                                            
axes[1][0].set_xlabel('Day of year')
axes[1][1].set_xlabel('Day of year')                                                                                                                                                                                                       
fig.suptitle('Coverage vs Demand across the year', fontsize=14)
plt.tight_layout()                                                                                                                                                                                                                         
plt.show()
                                                                                                                                                                                                                                            
# Summary stats by quarter
print(f"\n{'Quarter':<12} {'M-A viol':>8} {'T-A viol':>8} {'M-B viol':>8} {'T-B viol':>8} {'Total':>6}")
print("-" * 58)                                                                                                                                                                                                                            
total_viol = 0
for q, (start, end) in enumerate([(0,91),(91,182),(182,273),(273,365)], 1):                                                                                                                                                                
    viols = {}                                                                                                                                                                                                                             
    q_total = 0
    for (s, t), name in shift_team.items():                                                                                                                                                                                                
        v = int(np.sum(np.maximum(0, demand[start:end, s, t] - cov[start:end, s, t])))                                                                                                                                                     
        viols[name] = v                                                                                                                                                                                                                    
        q_total += v                                                                                                                                                                                                                       
    total_viol += q_total                                                                                                                                                                                                                  
    print(f"Q{q} ({start:3d}-{end:3d})  {viols['M-A']:>8} {viols['T-A']:>8} {viols['M-B']:>8} {viols['T-B']:>8} {q_total:>6}")
print("-" * 58)                                                                                                                                                                                                                            
print(f"{'Total':<12} {'':>8} {'':>8} {'':>8} {'':>8} {total_viol:>6}")
                                                                                                                                                                                                                                            
# Days worked distribution                                                                                                                                                                                                                 
print(f"\nDays worked/employee: {best_env.days_worked.tolist()}")                                                                                                                                                                          
print(f"Mean: {best_env.days_worked.mean():.1f}, Min: {best_env.days_worked.min()}, Max: {best_env.days_worked.max()}")
# Out:
# /tmp/ipykernel_5926/4012294004.py:28: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   mask_t    = torch.tensor([action_mask], dtype=torch.bool)
# Quarter      M-A viol T-A viol M-B viol T-B viol  Total
# ----------------------------------------------------------
# Q1 (  0- 91)        10       15       11       11     47
# Q2 ( 91-182)         7       15        9       11     42
# Q3 (182-273)         9       10       18       21     58
# Q4 (273-365)        37       29       32       37    135
# ----------------------------------------------------------
# Total                                               282
#
# Days worked/employee: [223, 223, 223, 222, 193, 223, 217, 223, 220, 223, 223, 223]
# Mean: 219.7, Min: 193, Max: 223
